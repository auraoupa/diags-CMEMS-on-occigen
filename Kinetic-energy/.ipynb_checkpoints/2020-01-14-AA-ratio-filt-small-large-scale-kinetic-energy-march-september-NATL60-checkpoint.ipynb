# %%
config='NATL60'
case='CJM165'
freq='1d'
region='GS'

year='2013'

# %%
from dask_jobqueue import SLURMCluster 
from dask.distributed import Client 
  
cluster = SLURMCluster(cores=28,name='make_profiles',walltime='00:30:00',job_extra=['--constraint=HSW24','--exclusive','--nodes=1'],memory='120GB',interface='ib0') 
cluster.scale(280)
cluster
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/bokeh/core.py:74: UserWarning:
# Failed to start diagnostics server on port 8787. [Errno 13] Permission denied
#   warnings.warn("\n" + msg)
# VBox(children=(HTML(value='<h2>SLURMCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    …

# %%
from dask.distributed import Client
client = Client(cluster)
client
# Out:
# <Client: scheduler='tcp://172.30.100.2:44269' processes=0 cores=0>

# %%
# !squeue -u albert7a
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            8611635     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611636     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611637     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611638     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611639     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611640     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611641     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611642     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611643     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8611644     hsw24 make_pro albert7a PD       0:00      1 (None)

# %%
import time
nb_workers = 0
while True:
    nb_workers = len(client.scheduler_info()["workers"])
    if nb_workers >= 2:
        break
    time.sleep(1)
print(nb_workers)
# Out:
# 111

# %%
## path for mdules

import sys
sys.path.insert(0,"/scratch/cnt0024/hmg2840/albert7a/DEV/git/xscale")
import xscale

sys.path.insert(0,"/scratch/cnt0024/hmg2840/albert7a/DEV/git/diags-CMEMS-on-occigen/common-lib/")
import GriddedData

import os
import sys
import numpy as np
import numpy.ma as ma
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cmocean
import glob
import time

# %matplotlib inline
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/merge.py:16: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
if region == 'EU':
    imin=3858
    imax=5076
    jmin=424
    jmax=3286
    
#cdffindij -w -80.418  -40.000   26.991   47.986 -c /store/molines/NATL60/NATL60-I/NATL60_coordinates_v4.nc
if region == 'GS':
    imin=63
    imax=2507
    jmin=29
    jmax=1611

# %%
## Dataset

gridfile='/store/molines/NATL60/NATL60-I/NATL60_coordinates_v4.nc'
maskfile='/store/molines/NATL60/NATL60-I/NATL60_v4.1_cdf_byte_mask.nc'
meshhgrfile='/store/molines/NATL60/NATL60-I/NATL60_v4.1_cdf_mesh_hgr.nc'
meshzgrfile='/store/molines/NATL60/NATL60-I/NATL60_v4.1_cdf_mesh_zgr.nc'

# %%
grid=xr.open_dataset(gridfile)
navlat= grid['nav_lat'][jmin:jmax,imin:imax]
navlon= grid['nav_lon'][jmin:jmax,imin:imax]

# %%
def compute_TKE(u2mean,v2mean):
    ua=0.5*(u2mean+u2mean.shift(x=1))
    va=0.5*(v2mean+v2mean.shift(y=1))
    uat=ua.rename({'depthu':'deptht'})
    vat=va.rename({'depthv':'deptht'})
    tke=0.5*(uat+vat)
    return tke
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)

# %%
def compute_EKE(u2,v2,u2mean,v2mean):
    ua=0.5*((-1*u2+u2mean)+(-1*u2.shift(x=1)+u2mean.shift(x=1)))
    va=0.5*((-1*v2+v2mean)+(-1*v2.shift(y=1)+v2mean.shift(y=1)))
    uat=ua.rename({'depthu':'deptht'})
    vat=va.rename({'depthv':'deptht'})
    eke=0.5*(uat+vat)
    return eke

# %%
month_name={1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
def plot_ratio_eke_tke_monthly(var,loncrs,latcrs,lon,lat,hpvarm,m,mm,config,case):
    if region == 'EU':
        fig, ax = plt.subplots(1,1,figsize=(10,15))
    if region == 'GS':
        fig, ax = plt.subplots(1,1,figsize=(15,10))
    ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
    ax.autoscale(tight=True)
    cont=np.isnan(hpvarm)
    gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                      alpha=0.5)
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlabel_style = {'size': 25, 'color': 'gray'}
    gl.ylabel_style = {'size': 25, 'color': 'gray'}
    
    ax.tick_params('both',labelsize=25)

    pcolor = ax.pcolormesh(loncrs,latcrs,ma.masked_invalid(var),cmap='rainbow',vmin=0,vmax=2,alpha=1)
    ax.contour(lon,lat,cont,alpha=0.5,linewidth=0.000001,antialiased=True,colors='black')
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    cbar.ax.tick_params(labelsize=25)
    cbar.set_label('Ratio of eke over tke in '+str(month_name[m])+' for '+config+'-'+case,fontsize=15)
    plt.savefig('Plots/'+config+region+'-'+case+'_y'+year+'m'+mm+'_ratio_eke_tke.png')

# %%
def plot_ratio(month,year):
    mm = "{:02d}".format(month)
    datadir='/store/molines/'+str(config)+'/'+str(config)+'-'+str(case)+'-S/'+str(freq)+'/'+str(year)+'/'
    filesU=sorted(glob.glob(datadir+'/'+str(config)+'-'+str(case)+'_y'+str(year)+'m'+str(mm)+'d??.'+str(freq)+'_gridU.nc'))
    filesV=sorted(glob.glob(datadir+'/'+str(config)+'-'+str(case)+'_y'+str(year)+'m'+str(mm)+'d??.'+str(freq)+'_gridV.nc'))
    dsU=xr.open_mfdataset(filesU, chunks={'x':700,'y':1000,'time_counter':10,'depthu':1})
    dsV=xr.open_mfdataset(filesV, chunks={'x':700,'y':1000,'time_counter':10,'depthv':1})
    u=dsU.vozocrtx[:,0,jmin:jmax,imin:imax]
    v=dsV.vomecrty[:,0,jmin:jmax,imin:imax]
    umean=u.mean(dim='time_counter')
    vmean=v.mean(dim='time_counter')
    umean2=umean*umean
    vmean2=vmean*vmean
    u2=u*u
    v2=v*v
    u2mean=u2.mean(dim='time_counter')
    v2mean=v2.mean(dim='time_counter')
    tke=compute_TKE(u2,v2)
    eke=compute_EKE(umean2,vmean2,u2mean,v2mean)
    tkemean=tke.mean(dim='time_counter')
    ratio=eke/(tkemean-eke)
    hpcurl=ratio
    hpcurl2 = hpcurl ** 2
    navlat2=np.array(navlat).squeeze()
    navlon2=np.array(navlon).squeeze()
    mgrd = GriddedData.grid2D(navlat=navlat2, navlon=navlon2)
    crs = GriddedData.grdCoarsener(mgrd,crs_factor=60)
    hpcurl2mc = crs.return_ravel(np.asarray(hpcurl2))
    hpcurl2mcm = np.mean(hpcurl2mc,axis=-3)
    latcrs=crs.return_ravel(np.asarray(navlat2))
    loncrs=crs.return_ravel(np.asarray(navlon2))
    latcrsm=np.mean(latcrs,axis=-3)
    loncrsm=np.mean(loncrs,axis=-3)
    plot_ratio_eke_tke_monthly(hpcurl2mcm,loncrsm,latcrsm,navlon,navlat,ratio,month,mm,config,case)

# %%
for month in [3,9]:
    plot_ratio(month,year)
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1366: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   result = matplotlib.axes.Axes.contour(self, *args, **kwargs)
# distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:41345'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 3)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:35265'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:40055'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:38745'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 3)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:41452'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 2)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:43822'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:37069'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 3)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:41028'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:37313'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:39164'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:35614'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:43023'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 4)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:43074'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 6)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:38880'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:41035'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 2)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:33794'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 5)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:33864'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 1)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:40967'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:34307'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:37450'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 7)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.101:38709'], ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 5)
# NoneType: None
# distributed.client - WARNING - Couldn't gather 21 keys, rescheduling {"('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 3)": ('tcp://172.30.6.101:41345',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 1)": ('tcp://172.30.6.101:35265',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 6)": ('tcp://172.30.6.101:40055',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 3)": ('tcp://172.30.6.101:38745',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 2)": ('tcp://172.30.6.101:41452',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 1)": ('tcp://172.30.6.101:43822',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 3)": ('tcp://172.30.6.101:37069',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 0)": ('tcp://172.30.6.101:41028',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 6)": ('tcp://172.30.6.101:37313',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 4)": ('tcp://172.30.6.101:39164',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 4)": ('tcp://172.30.6.101:35614',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 4)": ('tcp://172.30.6.101:43023',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 6)": ('tcp://172.30.6.101:43074',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 7)": ('tcp://172.30.6.101:38880',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 2)": ('tcp://172.30.6.101:41035',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 5)": ('tcp://172.30.6.101:33794',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 2, 1)": ('tcp://172.30.6.101:33864',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 0)": ('tcp://172.30.6.101:40967',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 3, 7)": ('tcp://172.30.6.101:34307',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 7)": ('tcp://172.30.6.101:37450',), "('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', 1, 5)": ('tcp://172.30.6.101:38709',)}
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# <ipython-input-30-6343b48dac38> in <module>
#       1 for month in [3,9]:
# ----> 2     plot_ratio(month,year)
#
# <ipython-input-28-f994429b63f2> in plot_ratio(month, year)
#       4     filesU=sorted(glob.glob(datadir+'/'+str(config)+'-'+str(case)+'_y'+str(year)+'m'+str(mm)+'d??.'+str(freq)+'_gridU.nc'))
#       5     filesV=sorted(glob.glob(datadir+'/'+str(config)+'-'+str(case)+'_y'+str(year)+'m'+str(mm)+'d??.'+str(freq)+'_gridV.nc'))
# ----> 6     dsU=xr.open_mfdataset(filesU, chunks={'x':700,'y':1000,'time_counter':10,'depthu':1})
#       7     dsV=xr.open_mfdataset(filesV, chunks={'x':700,'y':1000,'time_counter':10,'depthv':1})
#       8     u=dsU.vozocrtx[:,0,jmin:jmax,imin:imax]
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, autoclose, parallel, **kwargs)
#     717             data_vars=data_vars, coords=coords,
#     718             infer_order_from_coords=infer_order_from_coords,
# --> 719             ids=ids)
#     720     except ValueError:
#     721         for ds in datasets:
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in _auto_combine(datasets, concat_dims, compat, data_vars, coords, infer_order_from_coords, ids)
#     551     # Repeatedly concatenate then merge along each dimension
#     552     combined = _combine_nd(combined_ids, concat_dims, compat=compat,
# --> 553                            data_vars=data_vars, coords=coords)
#     554     return combined
#     555
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in _combine_nd(combined_ids, concat_dims, data_vars, coords, compat)
#     473                                                          data_vars=data_vars,
#     474                                                          coords=coords,
# --> 475                                                          compat=compat)
#     476     combined_ds = list(combined_ids.values())[0]
#     477     return combined_ds
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in _auto_combine_all_along_first_dim(combined_ids, dim, data_vars, coords, compat)
#     491         datasets = combined_ids.values()
#     492         new_combined_ids[new_id] = _auto_combine_1d(datasets, dim, compat,
# --> 493                                                     data_vars, coords)
#     494     return new_combined_ids
#     495
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in _auto_combine_1d(datasets, concat_dim, compat, data_vars, coords)
#     509         concatenated = [_auto_concat(list(ds_group), dim=dim,
#     510                                      data_vars=data_vars, coords=coords)
# --> 511                         for id, ds_group in grouped_by_vars]
#     512     else:
#     513         concatenated = datasets
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in <listcomp>(.0)
#     509         concatenated = [_auto_concat(list(ds_group), dim=dim,
#     510                                      data_vars=data_vars, coords=coords)
# --> 511                         for id, ds_group in grouped_by_vars]
#     512     else:
#     513         concatenated = datasets
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in _auto_concat(datasets, dim, data_vars, coords)
#     367                                  'explicitly')
#     368             dim, = concat_dims
# --> 369         return concat(datasets, dim=dim, data_vars=data_vars, coords=coords)
#     370
#     371
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in concat(objs, dim, data_vars, coords, compat, positions, indexers, mode, concat_over)
#     118         raise TypeError('can only concatenate xarray Dataset and DataArray '
#     119                         'objects, got %s' % type(first_obj))
# --> 120     return f(objs, dim, data_vars, coords, compat, positions)
#     121
#     122
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions)
#     228     datasets = align(*datasets, join='outer', copy=False, exclude=[dim])
#     229
# --> 230     concat_over, equals = _calc_concat_over(datasets, dim, data_vars, coords)
#     231
#     232     def insert_result_variable(k, v):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in _calc_concat_over(datasets, dim, data_vars, coords)
#     209
#     210     process_subset_opt(data_vars, 'data_vars')
# --> 211     process_subset_opt(coords, 'coords')
#     212     return concat_over, equals
#     213
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/combine.py in process_subset_opt(opt, subset)
#     174                         computed = []
#     175                         for ds_rhs in datasets[1:]:
# --> 176                             v_rhs = ds_rhs.variables[k].compute()
#     177                             computed.append(v_rhs)
#     178                             if not v_lhs.equals(v_rhs):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/variable.py in compute(self, **kwargs)
#     342         """
#     343         new = self.copy(deep=False)
# --> 344         return new.load(**kwargs)
#     345
#     346     def __dask_graph__(self):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/variable.py in load(self, **kwargs)
#     318         """
#     319         if isinstance(self._data, dask_array_type):
# --> 320             self._data = as_compatible_data(self._data.compute(**kwargs))
#     321         elif not isinstance(self._data, np.ndarray):
#     322             self._data = np.asarray(self._data)
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     396     keys = [x.__dask_keys__() for x in collections]
#     397     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 398     results = schedule(dsk, keys, **kwargs)
#     399     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     400
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2566                     should_rejoin = False
#    2567             try:
# -> 2568                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2569             finally:
#    2570                 for f in futures.values():
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in gather(self, futures, errors, maxsize, direct, asynchronous)
#    1820                 direct=direct,
#    1821                 local_worker=local_worker,
# -> 1822                 asynchronous=asynchronous,
#    1823             )
#    1824
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in sync(self, func, *args, **kwargs)
#     751             return future
#     752         else:
# --> 753             return sync(self.loop, func, *args, **kwargs)
#     754
#     755     def __repr__(self):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, *args, **kwargs)
#     329             e.wait(10)
#     330     if error[0]:
# --> 331         six.reraise(*error[0])
#     332     else:
#     333         return result[0]
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py in f()
#     314             if timeout is not None:
#     315                 future = gen.with_timeout(timedelta(seconds=timeout), future)
# --> 316             result[0] = yield future
#     317         except Exception as exc:
#     318             error[0] = sys.exc_info()
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     740                     if exc_info is not None:
#     741                         try:
# --> 742                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     743                         finally:
#     744                             # Break up a reference to itself
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1651                             six.reraise(CancelledError, CancelledError(key), None)
#    1652                         else:
# -> 1653                             six.reraise(type(exception), exception, traceback)
#    1654                     if errors == "skip":
#    1655                         bad_keys.add(key)
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# KilledWorker: ('open_dataset-65b4759e11df4d527728918a252c752cnav_lat-54be3a4ef428fc6f00cf1f406a14b747', <Worker 'tcp://172.30.8.84:38528', memory: 0, processing: 1>)

# %%
#test if workers still active
print(len(client.scheduler_info()["workers"]))
# Out:
# 280
