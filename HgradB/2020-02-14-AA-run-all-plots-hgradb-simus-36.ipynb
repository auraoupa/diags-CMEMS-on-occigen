# %%
import papermill as pm

# %%
for config in ['EU36']:
    for case in ['MPC001','MPC002','MPC003']:
        pm.execute_notebook('/scratch/cnt0024/hmg2840/albert7a/DEV/git/diags-CMEMS-on-occigen/HgradB/2020-02-13-AA-horizontal-gradient-fine-scale-buoyancy-boxcar-average-regional-all-simus-36.ipynb','/scratch/cnt0024/hmg2840/albert7a/DEV/git/diags-CMEMS-on-occigen/HgradB/2020-02-14-output-'+str(config)+str(case)+'.ipynb',parameters=dict(config=config,case=case))

# %%
for config in ['GS36']:
    for case in ['MPC002','MPC003']:
        pm.execute_notebook('/scratch/cnt0024/hmg2840/albert7a/DEV/git/diags-CMEMS-on-occigen/HgradB/2020-02-13-AA-horizontal-gradient-fine-scale-buoyancy-boxcar-average-regional-all-simus-36.ipynb','/scratch/cnt0024/hmg2840/albert7a/DEV/git/diags-CMEMS-on-occigen/HgradB/2020-02-14-output-'+str(config)+str(case)+'.ipynb',parameters=dict(config=config,case=case))

# %%
pm.execute_notebook('/scratch/cnt0024/hmg2840/albert7a/DEV/git/diags-CMEMS-on-occigen/HgradB/2020-02-13-AA-horizontal-gradient-fine-scale-buoyancy-boxcar-average-regional-all-simus-36.ipynb','/scratch/cnt0024/hmg2840/albert7a/DEV/git/diags-CMEMS-on-occigen/HgradB/2020-02-14-output-'+str(config)+str(case)+'.ipynb',parameters=dict(config='EU36',case='MPC001'))
# Out:
# ...
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-02-17T08:29:21.736262',
#      'end_time': '2020-02-17T08:29:21.750094',
#      'duration': 0.013832,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "config='GS36'\ncase='MPC001'\nfreq='1d'\n\nyear='2012'\n"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-02-17T08:29:21.759390',
#      'end_time': '2020-02-17T08:29:21.771380',
#      'duration': 0.01199,
#      'status': 'completed'}},
#    'execution_count': 2,
#    'source': '# Parameters\nconfig = "EU36"\ncase = "MPC001"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-02-17T08:29:21.778209',
# ...
