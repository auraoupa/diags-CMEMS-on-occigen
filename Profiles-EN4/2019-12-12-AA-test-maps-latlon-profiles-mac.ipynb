# %% [markdown]
# ## Plot the locations of all profiles

# %%
import numpy as np
import dask
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import glob as glob
import time
from datetime import date
import io
import json
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
# Out:
# /Users/auraoupa/anaconda2/envs/pangeo-cloud/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
def map_profiles_from_jsonfile(jsonfile,title):
    
    sourcefile=open(jsonfile,'rU',encoding='utf-8')
    infos=json.load(sourcefile)
    nb_profilesEN4=len(infos)

    all_lat=np.zeros((nb_profilesEN4))
    all_lon=np.zeros((nb_profilesEN4))
    
    list_profiles=infos.keys()
    
    for prof in np.arange(nb_profilesEN4):
        reference =  str(list(list_profiles)[prof])
        lat_prof = infos[reference]['latitude']
        lon_prof = infos[reference]['longitude']
        all_lat[prof]=lat_prof
        all_lon[prof]=lon_prof


    fig=plt.figure(figsize=(20,15))
    ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
#    ax.set_extent((lonmin, lonmax, latmin, latmax))
    ax.coastlines(resolution="10m")
    gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                      alpha=0.5)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax.tick_params('both',labelsize=22)

    plt.scatter(all_lon, all_lat, c='g', linewidth='0', s=18);
    plt.title(title, size=20);

# %%
map_profiles_from_jsonfile('/Users/auraoupa/Work/git/CMEMS-diags/Comp_ARGO_profiles/osmo_autumn.json','OSMO autumn')
# Out:
# /Users/auraoupa/anaconda2/envs/pangeo-cloud/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: 'U' mode is deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
map_profiles_from_jsonfile('/Users/auraoupa/Work/git/CMEMS-diags/Comp_ARGO_profiles/medred_201308.json','med red 201308')
# Out:
# /Users/auraoupa/anaconda2/envs/pangeo-cloud/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: 'U' mode is deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def map_profiles_from_jsonfile(jsonfile,title):
    
    sourcefile=open(jsonfile,'rU',encoding='utf-8')
    infos=json.load(sourcefile)
    nb_profilesEN4=len(infos)

    all_lat=np.zeros((nb_profilesEN4))
    all_lon=np.zeros((nb_profilesEN4))
    
    list_profiles=infos.keys()
    
    for prof in np.arange(nb_profilesEN4):
        reference =  str(list(list_profiles)[prof])
        lat_prof = int(infos[reference]['latitude'])
        lon_prof = int(infos[reference]['longitude'])
        all_lat[prof]=lat_prof
        all_lon[prof]=lon_prof


    fig=plt.figure(figsize=(20,15))
    ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
#    ax.set_extent((lonmin, lonmax, latmin, latmax))
    ax.coastlines(resolution="10m")
    gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                      alpha=0.5)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax.tick_params('both',labelsize=22)

    plt.plot(all_lon, all_lat, 'r.', transform=ccrs.PlateCarree());
    plt.title(title, size=20);

# %%
map_profiles_from_jsonfile('/Users/auraoupa/Work/git/CMEMS-diags/Comp_ARGO_profiles/medred_201308.json','med red 201308')
# Out:
# /Users/auraoupa/anaconda2/envs/pangeo-cloud/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: 'U' mode is deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
    sourcefile=open('/Users/auraoupa/Work/git/CMEMS-diags/Comp_ARGO_profiles/medred_201308.json','rU',encoding='utf-8')
    infos=json.load(sourcefile)
    nb_profilesEN4=len(infos)

    all_lat=np.zeros((nb_profilesEN4))
    all_lon=np.zeros((nb_profilesEN4))
    
    list_profiles=infos.keys()
    
    for prof in np.arange(nb_profilesEN4):
        reference =  str(list(list_profiles)[prof])
        lat_prof = infos[reference]['latitude']
        lon_prof = infos[reference]['longitude']
        all_lat[prof]=lat_prof
        all_lon[prof]=lon_prof
# Out:
# /Users/auraoupa/anaconda2/envs/pangeo-cloud/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
print(all_lat,all_lon)
# Out:
# [37.15       37.57       38.703      37.884      36.316      37.482
#  37.884      38.763      37.374      37.056      38.82       37.904
#  37.345      38.14304333 39.95487167 38.854      37.834      37.316
#  37.45       38.26149167 37.781      37.121      39.88725833 37.345
#  38.869      38.37004333 38.899      37.414      37.771      39.749675
#  37.421      38.24441167 38.849      39.71752667 37.057      37.826     ] [-0.728       2.802       3.957       0.213      -0.531       2.819
#   0.222       3.831       2.955      -1.19        3.817       0.214
#   3.185       4.33876167  1.175315    3.836       0.304       3.399
#  -0.455       4.00326667  0.276      -1.264       1.09333833  3.645
#   3.818       3.89767167  3.854       3.842       0.285       1.051795
#   3.975       4.05944     4.029       0.980945   -1.194       0.325     ]
