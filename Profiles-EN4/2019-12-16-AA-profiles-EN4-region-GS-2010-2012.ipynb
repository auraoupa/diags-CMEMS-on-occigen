# %% [markdown]
# ## Produce the json file listing all profiles in GS region

# %%
import numpy as np
import dask
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import glob as glob
import time
from datetime import date
import io
import json
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/merge.py:16: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
latmin,latmax,lonmin,lonmax=(27,48,-81,-40)
datemin,datemax=('2010-01-01','2012-12-31')
jsonfile='GS_y2010-2011-2012.json'

# %%
# !ls /scratch/cnt0024/hmg2840/albert7a/EN4/
# Out:
# 20100101_prof.nc  20110110_prof.nc  20120119_prof.nc
# 20100102_prof.nc  20110111_prof.nc  20120120_prof.nc
# 20100103_prof.nc  20110112_prof.nc  20120121_prof.nc
# 20100104_prof.nc  20110113_prof.nc  20120122_prof.nc
# 20100105_prof.nc  20110114_prof.nc  20120123_prof.nc
# 20100106_prof.nc  20110115_prof.nc  20120124_prof.nc
# 20100107_prof.nc  20110116_prof.nc  20120125_prof.nc
# 20100108_prof.nc  20110117_prof.nc  20120126_prof.nc
# 20100109_prof.nc  20110118_prof.nc  20120127_prof.nc
# 20100110_prof.nc  20110119_prof.nc  20120128_prof.nc
# 20100111_prof.nc  20110120_prof.nc  20120129_prof.nc
# 20100112_prof.nc  20110121_prof.nc  20120130_prof.nc
# 20100113_prof.nc  20110122_prof.nc  20120131_prof.nc
# 20100114_prof.nc  20110123_prof.nc  20120201_prof.nc
# 20100115_prof.nc  20110124_prof.nc  20120202_prof.nc
# 20100116_prof.nc  20110125_prof.nc  20120203_prof.nc
# 20100117_prof.nc  20110126_prof.nc  20120204_prof.nc
# 20100118_prof.nc  20110127_prof.nc  20120205_prof.nc
# 20100119_prof.nc  20110128_prof.nc  20120206_prof.nc
# 20100120_prof.nc  20110129_prof.nc  20120207_prof.nc
# 20100121_prof.nc  20110130_prof.nc  20120208_prof.nc
# 20100122_prof.nc  20110131_prof.nc  20120209_prof.nc
# 20100123_prof.nc  20110201_prof.nc  20120210_prof.nc
# 20100124_prof.nc  20110202_prof.nc  20120211_prof.nc
# 20100125_prof.nc  20110203_prof.nc  20120212_prof.nc
# 20100126_prof.nc  20110204_prof.nc  20120213_prof.nc
# 20100127_prof.nc  20110205_prof.nc  20120214_prof.nc
# 20100128_prof.nc  20110206_prof.nc  20120215_prof.nc
# 20100129_prof.nc  20110207_prof.nc  20120216_prof.nc
# 20100130_prof.nc  20110208_prof.nc  20120217_prof.nc
# 20100131_prof.nc  20110209_prof.nc  20120218_prof.nc
# 20100201_prof.nc  20110210_prof.nc  20120219_prof.nc
# 20100202_prof.nc  20110211_prof.nc  20120220_prof.nc
# 20100203_prof.nc  20110212_prof.nc  20120221_prof.nc
# 20100204_prof.nc  20110213_prof.nc  20120222_prof.nc
# 20100205_prof.nc  20110214_prof.nc  20120223_prof.nc
# 20100206_prof.nc  20110215_prof.nc  20120224_prof.nc
# 20100207_prof.nc  20110216_prof.nc  20120225_prof.nc
# 20100208_prof.nc  20110217_prof.nc  20120226_prof.nc
# 20100209_prof.nc  20110218_prof.nc  20120227_prof.nc
# 20100210_prof.nc  20110219_prof.nc  20120228_prof.nc
# 20100211_prof.nc  20110220_prof.nc  20120229_prof.nc
# 20100212_prof.nc  20110221_prof.nc  20120301_prof.nc
# 20100213_prof.nc  20110222_prof.nc  20120302_prof.nc
# 20100214_prof.nc  20110223_prof.nc  20120303_prof.nc
# 20100215_prof.nc  20110224_prof.nc  20120304_prof.nc
# 20100216_prof.nc  20110225_prof.nc  20120305_prof.nc
# 20100217_prof.nc  20110226_prof.nc  20120306_prof.nc
# 20100218_prof.nc  20110227_prof.nc  20120307_prof.nc
# 20100219_prof.nc  20110228_prof.nc  20120308_prof.nc
# 20100220_prof.nc  20110301_prof.nc  20120309_prof.nc
# 20100221_prof.nc  20110302_prof.nc  20120310_prof.nc
# 20100222_prof.nc  20110303_prof.nc  20120311_prof.nc
# 20100223_prof.nc  20110304_prof.nc  20120312_prof.nc
# 20100224_prof.nc  20110305_prof.nc  20120313_prof.nc
# 20100225_prof.nc  20110306_prof.nc  20120314_prof.nc
# 20100226_prof.nc  20110307_prof.nc  20120315_prof.nc
# 20100227_prof.nc  20110308_prof.nc  20120316_prof.nc
# 20100228_prof.nc  20110309_prof.nc  20120317_prof.nc
# 20100301_prof.nc  20110310_prof.nc  20120318_prof.nc
# 20100302_prof.nc  20110311_prof.nc  20120319_prof.nc
# 20100303_prof.nc  20110312_prof.nc  20120320_prof.nc
# 20100304_prof.nc  20110313_prof.nc  20120321_prof.nc
# 20100305_prof.nc  20110314_prof.nc  20120322_prof.nc
# 20100306_prof.nc  20110315_prof.nc  20120323_prof.nc
# 20100307_prof.nc  20110316_prof.nc  20120324_prof.nc
# 20100308_prof.nc  20110317_prof.nc  20120325_prof.nc
# 20100309_prof.nc  20110318_prof.nc  20120326_prof.nc
# 20100310_prof.nc  20110319_prof.nc  20120327_prof.nc
# 20100311_prof.nc  20110320_prof.nc  20120328_prof.nc
# 20100312_prof.nc  20110321_prof.nc  20120329_prof.nc
# 20100313_prof.nc  20110322_prof.nc  20120330_prof.nc
# 20100314_prof.nc  20110323_prof.nc  20120331_prof.nc
# 20100315_prof.nc  20110324_prof.nc  20120401_prof.nc
# 20100316_prof.nc  20110325_prof.nc  20120402_prof.nc
# 20100317_prof.nc  20110326_prof.nc  20120403_prof.nc
# 20100318_prof.nc  20110327_prof.nc  20120404_prof.nc
# 20100319_prof.nc  20110328_prof.nc  20120405_prof.nc
# 20100320_prof.nc  20110329_prof.nc  20120406_prof.nc
# 20100321_prof.nc  20110330_prof.nc  20120407_prof.nc
# 20100322_prof.nc  20110331_prof.nc  20120408_prof.nc
# 20100323_prof.nc  20110401_prof.nc  20120409_prof.nc
# 20100324_prof.nc  20110402_prof.nc  20120410_prof.nc
# 20100325_prof.nc  20110403_prof.nc  20120411_prof.nc
# 20100326_prof.nc  20110404_prof.nc  20120412_prof.nc
# 20100327_prof.nc  20110405_prof.nc  20120413_prof.nc
# 20100328_prof.nc  20110406_prof.nc  20120414_prof.nc
# 20100329_prof.nc  20110407_prof.nc  20120415_prof.nc
# 20100330_prof.nc  20110408_prof.nc  20120416_prof.nc
# 20100331_prof.nc  20110409_prof.nc  20120417_prof.nc
# 20100401_prof.nc  20110410_prof.nc  20120418_prof.nc
# 20100402_prof.nc  20110411_prof.nc  20120419_prof.nc
# 20100403_prof.nc  20110412_prof.nc  20120420_prof.nc
# 20100404_prof.nc  20110413_prof.nc  20120421_prof.nc
# 20100405_prof.nc  20110414_prof.nc  20120422_prof.nc
# 20100406_prof.nc  20110415_prof.nc  20120423_prof.nc
# 20100407_prof.nc  20110416_prof.nc  20120424_prof.nc
# 20100408_prof.nc  20110417_prof.nc  20120425_prof.nc
# 20100409_prof.nc  20110418_prof.nc  20120426_prof.nc
# 20100410_prof.nc  20110419_prof.nc  20120427_prof.nc
# 20100411_prof.nc  20110420_prof.nc  20120428_prof.nc
# 20100412_prof.nc  20110421_prof.nc  20120429_prof.nc
# 20100413_prof.nc  20110422_prof.nc  20120430_prof.nc
# 20100414_prof.nc  20110423_prof.nc  20120501_prof.nc
# 20100415_prof.nc  20110424_prof.nc  20120502_prof.nc
# 20100416_prof.nc  20110425_prof.nc  20120503_prof.nc
# 20100417_prof.nc  20110426_prof.nc  20120504_prof.nc
# 20100418_prof.nc  20110427_prof.nc  20120505_prof.nc
# 20100419_prof.nc  20110428_prof.nc  20120506_prof.nc
# 20100420_prof.nc  20110429_prof.nc  20120507_prof.nc
# 20100421_prof.nc  20110430_prof.nc  20120508_prof.nc
# 20100422_prof.nc  20110501_prof.nc  20120509_prof.nc
# 20100423_prof.nc  20110502_prof.nc  20120510_prof.nc
# 20100424_prof.nc  20110503_prof.nc  20120511_prof.nc
# 20100425_prof.nc  20110504_prof.nc  20120512_prof.nc
# 20100426_prof.nc  20110505_prof.nc  20120513_prof.nc
# 20100427_prof.nc  20110506_prof.nc  20120514_prof.nc
# 20100428_prof.nc  20110507_prof.nc  20120515_prof.nc
# 20100429_prof.nc  20110508_prof.nc  20120516_prof.nc
# 20100430_prof.nc  20110509_prof.nc  20120517_prof.nc
# 20100501_prof.nc  20110510_prof.nc  20120518_prof.nc
# 20100502_prof.nc  20110511_prof.nc  20120519_prof.nc
# 20100503_prof.nc  20110512_prof.nc  20120520_prof.nc
# 20100504_prof.nc  20110513_prof.nc  20120521_prof.nc
# 20100505_prof.nc  20110514_prof.nc  20120522_prof.nc
# 20100506_prof.nc  20110515_prof.nc  20120523_prof.nc
# 20100507_prof.nc  20110516_prof.nc  20120524_prof.nc
# 20100508_prof.nc  20110517_prof.nc  20120525_prof.nc
# 20100509_prof.nc  20110518_prof.nc  20120526_prof.nc
# 20100510_prof.nc  20110519_prof.nc  20120527_prof.nc
# 20100511_prof.nc  20110520_prof.nc  20120528_prof.nc
# 20100512_prof.nc  20110521_prof.nc  20120529_prof.nc
# 20100513_prof.nc  20110522_prof.nc  20120530_prof.nc
# 20100514_prof.nc  20110523_prof.nc  20120531_prof.nc
# 20100515_prof.nc  20110524_prof.nc  20120601_prof.nc
# 20100516_prof.nc  20110525_prof.nc  20120602_prof.nc
# 20100517_prof.nc  20110526_prof.nc  20120603_prof.nc
# 20100518_prof.nc  20110527_prof.nc  20120604_prof.nc
# 20100519_prof.nc  20110528_prof.nc  20120605_prof.nc
# 20100520_prof.nc  20110529_prof.nc  20120606_prof.nc
# 20100521_prof.nc  20110530_prof.nc  20120607_prof.nc
# 20100522_prof.nc  20110531_prof.nc  20120608_prof.nc
# 20100523_prof.nc  20110601_prof.nc  20120609_prof.nc
# 20100524_prof.nc  20110602_prof.nc  20120610_prof.nc
# 20100525_prof.nc  20110603_prof.nc  20120611_prof.nc
# 20100526_prof.nc  20110604_prof.nc  20120612_prof.nc
# 20100527_prof.nc  20110605_prof.nc  20120613_prof.nc
# 20100528_prof.nc  20110606_prof.nc  20120614_prof.nc
# 20100529_prof.nc  20110607_prof.nc  20120615_prof.nc
# 20100530_prof.nc  20110608_prof.nc  20120616_prof.nc
# 20100531_prof.nc  20110609_prof.nc  20120617_prof.nc
# 20100601_prof.nc  20110610_prof.nc  20120618_prof.nc
# 20100602_prof.nc  20110611_prof.nc  20120619_prof.nc
# 20100603_prof.nc  20110612_prof.nc  20120620_prof.nc
# 20100604_prof.nc  20110613_prof.nc  20120621_prof.nc
# 20100605_prof.nc  20110614_prof.nc  20120622_prof.nc
# 20100606_prof.nc  20110615_prof.nc  20120623_prof.nc
# 20100607_prof.nc  20110616_prof.nc  20120624_prof.nc
# 20100608_prof.nc  20110617_prof.nc  20120625_prof.nc
# 20100609_prof.nc  20110618_prof.nc  20120626_prof.nc
# 20100610_prof.nc  20110619_prof.nc  20120627_prof.nc
# 20100611_prof.nc  20110620_prof.nc  20120628_prof.nc
# 20100612_prof.nc  20110621_prof.nc  20120629_prof.nc
# 20100613_prof.nc  20110622_prof.nc  20120630_prof.nc
# 20100614_prof.nc  20110623_prof.nc  20120701_prof.nc
# 20100615_prof.nc  20110624_prof.nc  20120702_prof.nc
# 20100616_prof.nc  20110625_prof.nc  20120703_prof.nc
# 20100617_prof.nc  20110626_prof.nc  20120704_prof.nc
# 20100618_prof.nc  20110627_prof.nc  20120705_prof.nc
# 20100619_prof.nc  20110628_prof.nc  20120706_prof.nc
# 20100620_prof.nc  20110629_prof.nc  20120707_prof.nc
# 20100621_prof.nc  20110630_prof.nc  20120708_prof.nc
# 20100622_prof.nc  20110701_prof.nc  20120709_prof.nc
# 20100623_prof.nc  20110702_prof.nc  20120710_prof.nc
# 20100624_prof.nc  20110703_prof.nc  20120711_prof.nc
# 20100625_prof.nc  20110704_prof.nc  20120712_prof.nc
# 20100626_prof.nc  20110705_prof.nc  20120713_prof.nc
# 20100627_prof.nc  20110706_prof.nc  20120714_prof.nc
# 20100628_prof.nc  20110707_prof.nc  20120715_prof.nc
# 20100629_prof.nc  20110708_prof.nc  20120716_prof.nc
# 20100630_prof.nc  20110709_prof.nc  20120717_prof.nc
# 20100701_prof.nc  20110710_prof.nc  20120718_prof.nc
# 20100702_prof.nc  20110711_prof.nc  20120719_prof.nc
# 20100703_prof.nc  20110712_prof.nc  20120720_prof.nc
# 20100704_prof.nc  20110713_prof.nc  20120721_prof.nc
# 20100705_prof.nc  20110714_prof.nc  20120722_prof.nc
# 20100706_prof.nc  20110715_prof.nc  20120723_prof.nc
# 20100707_prof.nc  20110716_prof.nc  20120724_prof.nc
# 20100708_prof.nc  20110717_prof.nc  20120725_prof.nc
# 20100709_prof.nc  20110718_prof.nc  20120726_prof.nc
# 20100710_prof.nc  20110719_prof.nc  20120727_prof.nc
# 20100711_prof.nc  20110720_prof.nc  20120728_prof.nc
# 20100712_prof.nc  20110721_prof.nc  20120729_prof.nc
# 20100713_prof.nc  20110722_prof.nc  20120730_prof.nc
# 20100714_prof.nc  20110723_prof.nc  20120731_prof.nc
# 20100715_prof.nc  20110724_prof.nc  20120801_prof.nc
# 20100716_prof.nc  20110725_prof.nc  20120802_prof.nc
# 20100717_prof.nc  20110726_prof.nc  20120803_prof.nc
# 20100718_prof.nc  20110727_prof.nc  20120804_prof.nc
# 20100719_prof.nc  20110728_prof.nc  20120805_prof.nc
# 20100720_prof.nc  20110729_prof.nc  20120806_prof.nc
# 20100721_prof.nc  20110730_prof.nc  20120807_prof.nc
# 20100722_prof.nc  20110731_prof.nc  20120808_prof.nc
# 20100723_prof.nc  20110801_prof.nc  20120809_prof.nc
# 20100724_prof.nc  20110802_prof.nc  20120810_prof.nc
# 20100725_prof.nc  20110803_prof.nc  20120811_prof.nc
# 20100726_prof.nc  20110804_prof.nc  20120812_prof.nc
# 20100727_prof.nc  20110805_prof.nc  20120813_prof.nc
# 20100728_prof.nc  20110806_prof.nc  20120814_prof.nc
# 20100729_prof.nc  20110807_prof.nc  20120815_prof.nc
# 20100730_prof.nc  20110808_prof.nc  20120816_prof.nc
# 20100731_prof.nc  20110809_prof.nc  20120817_prof.nc
# 20100801_prof.nc  20110810_prof.nc  20120818_prof.nc
# 20100802_prof.nc  20110811_prof.nc  20120819_prof.nc
# 20100803_prof.nc  20110812_prof.nc  20120820_prof.nc
# 20100804_prof.nc  20110813_prof.nc  20120821_prof.nc
# 20100805_prof.nc  20110814_prof.nc  20120822_prof.nc
# 20100806_prof.nc  20110815_prof.nc  20120823_prof.nc
# 20100807_prof.nc  20110816_prof.nc  20120824_prof.nc
# 20100808_prof.nc  20110817_prof.nc  20120825_prof.nc
# 20100809_prof.nc  20110818_prof.nc  20120826_prof.nc
# 20100810_prof.nc  20110819_prof.nc  20120827_prof.nc
# 20100811_prof.nc  20110820_prof.nc  20120828_prof.nc
# 20100812_prof.nc  20110821_prof.nc  20120829_prof.nc
# 20100813_prof.nc  20110822_prof.nc  20120830_prof.nc
# 20100814_prof.nc  20110823_prof.nc  20120831_prof.nc
# 20100815_prof.nc  20110824_prof.nc  20120901_prof.nc
# 20100816_prof.nc  20110825_prof.nc  20120902_prof.nc
# 20100817_prof.nc  20110826_prof.nc  20120903_prof.nc
# 20100818_prof.nc  20110827_prof.nc  20120904_prof.nc
# 20100819_prof.nc  20110828_prof.nc  20120905_prof.nc
# 20100820_prof.nc  20110829_prof.nc  20120906_prof.nc
# 20100821_prof.nc  20110830_prof.nc  20120907_prof.nc
# 20100822_prof.nc  20110831_prof.nc  20120908_prof.nc
# 20100823_prof.nc  20110901_prof.nc  20120909_prof.nc
# 20100824_prof.nc  20110902_prof.nc  20120910_prof.nc
# 20100825_prof.nc  20110903_prof.nc  20120911_prof.nc
# 20100826_prof.nc  20110904_prof.nc  20120912_prof.nc
# 20100827_prof.nc  20110905_prof.nc  20120913_prof.nc
# 20100828_prof.nc  20110906_prof.nc  20120914_prof.nc
# 20100829_prof.nc  20110907_prof.nc  20120915_prof.nc
# 20100830_prof.nc  20110908_prof.nc  20120916_prof.nc
# 20100831_prof.nc  20110909_prof.nc  20120917_prof.nc
# 20100901_prof.nc  20110910_prof.nc  20120918_prof.nc
# 20100902_prof.nc  20110911_prof.nc  20120919_prof.nc
# 20100903_prof.nc  20110912_prof.nc  20120920_prof.nc
# 20100904_prof.nc  20110913_prof.nc  20120921_prof.nc
# 20100905_prof.nc  20110914_prof.nc  20120922_prof.nc
# 20100906_prof.nc  20110915_prof.nc  20120923_prof.nc
# 20100907_prof.nc  20110916_prof.nc  20120924_prof.nc
# 20100908_prof.nc  20110917_prof.nc  20120925_prof.nc
# 20100909_prof.nc  20110918_prof.nc  20120926_prof.nc
# 20100910_prof.nc  20110919_prof.nc  20120927_prof.nc
# 20100911_prof.nc  20110920_prof.nc  20120928_prof.nc
# 20100912_prof.nc  20110921_prof.nc  20120929_prof.nc
# 20100913_prof.nc  20110922_prof.nc  20120930_prof.nc
# 20100914_prof.nc  20110923_prof.nc  20121001_prof.nc
# 20100915_prof.nc  20110924_prof.nc  20121002_prof.nc
# 20100916_prof.nc  20110925_prof.nc  20121003_prof.nc
# 20100917_prof.nc  20110926_prof.nc  20121004_prof.nc
# 20100918_prof.nc  20110927_prof.nc  20121005_prof.nc
# 20100919_prof.nc  20110928_prof.nc  20121006_prof.nc
# 20100920_prof.nc  20110929_prof.nc  20121007_prof.nc
# 20100921_prof.nc  20110930_prof.nc  20121008_prof.nc
# 20100922_prof.nc  20111001_prof.nc  20121009_prof.nc
# 20100923_prof.nc  20111002_prof.nc  20121010_prof.nc
# 20100924_prof.nc  20111003_prof.nc  20121011_prof.nc
# 20100925_prof.nc  20111004_prof.nc  20121012_prof.nc
# 20100926_prof.nc  20111005_prof.nc  20121013_prof.nc
# 20100927_prof.nc  20111006_prof.nc  20121014_prof.nc
# 20100928_prof.nc  20111007_prof.nc  20121015_prof.nc
# 20100929_prof.nc  20111008_prof.nc  20121016_prof.nc
# 20100930_prof.nc  20111009_prof.nc  20121017_prof.nc
# 20101001_prof.nc  20111010_prof.nc  20121018_prof.nc
# 20101002_prof.nc  20111011_prof.nc  20121019_prof.nc
# 20101003_prof.nc  20111012_prof.nc  20121020_prof.nc
# 20101004_prof.nc  20111013_prof.nc  20121021_prof.nc
# 20101005_prof.nc  20111014_prof.nc  20121022_prof.nc
# 20101006_prof.nc  20111015_prof.nc  20121023_prof.nc
# 20101007_prof.nc  20111016_prof.nc  20121024_prof.nc
# 20101008_prof.nc  20111017_prof.nc  20121025_prof.nc
# 20101009_prof.nc  20111018_prof.nc  20121026_prof.nc
# 20101010_prof.nc  20111019_prof.nc  20121027_prof.nc
# 20101011_prof.nc  20111020_prof.nc  20121028_prof.nc
# 20101012_prof.nc  20111021_prof.nc  20121029_prof.nc
# 20101013_prof.nc  20111022_prof.nc  20121030_prof.nc
# 20101014_prof.nc  20111023_prof.nc  20121031_prof.nc
# 20101015_prof.nc  20111024_prof.nc  20121101_prof.nc
# 20101016_prof.nc  20111025_prof.nc  20121102_prof.nc
# 20101017_prof.nc  20111026_prof.nc  20121103_prof.nc
# 20101018_prof.nc  20111027_prof.nc  20121104_prof.nc
# 20101019_prof.nc  20111028_prof.nc  20121105_prof.nc
# 20101020_prof.nc  20111029_prof.nc  20121106_prof.nc
# 20101021_prof.nc  20111030_prof.nc  20121107_prof.nc
# 20101022_prof.nc  20111031_prof.nc  20121108_prof.nc
# 20101023_prof.nc  20111101_prof.nc  20121109_prof.nc
# 20101024_prof.nc  20111102_prof.nc  20121110_prof.nc
# 20101025_prof.nc  20111103_prof.nc  20121111_prof.nc
# 20101026_prof.nc  20111104_prof.nc  20121112_prof.nc
# 20101027_prof.nc  20111105_prof.nc  20121113_prof.nc
# 20101028_prof.nc  20111106_prof.nc  20121114_prof.nc
# 20101029_prof.nc  20111107_prof.nc  20121115_prof.nc
# 20101030_prof.nc  20111108_prof.nc  20121116_prof.nc
# 20101031_prof.nc  20111109_prof.nc  20121117_prof.nc
# 20101101_prof.nc  20111110_prof.nc  20121118_prof.nc
# 20101102_prof.nc  20111111_prof.nc  20121119_prof.nc
# 20101103_prof.nc  20111112_prof.nc  20121120_prof.nc
# 20101104_prof.nc  20111113_prof.nc  20121121_prof.nc
# 20101105_prof.nc  20111114_prof.nc  20121122_prof.nc
# 20101106_prof.nc  20111115_prof.nc  20121123_prof.nc
# 20101107_prof.nc  20111116_prof.nc  20121124_prof.nc
# 20101108_prof.nc  20111117_prof.nc  20121125_prof.nc
# 20101109_prof.nc  20111118_prof.nc  20121126_prof.nc
# 20101110_prof.nc  20111119_prof.nc  20121127_prof.nc
# 20101111_prof.nc  20111120_prof.nc  20121128_prof.nc
# 20101112_prof.nc  20111121_prof.nc  20121129_prof.nc
# 20101113_prof.nc  20111122_prof.nc  20121130_prof.nc
# 20101114_prof.nc  20111123_prof.nc  20121201_prof.nc
# 20101115_prof.nc  20111124_prof.nc  20121202_prof.nc
# 20101116_prof.nc  20111125_prof.nc  20121203_prof.nc
# 20101117_prof.nc  20111126_prof.nc  20121204_prof.nc
# 20101118_prof.nc  20111127_prof.nc  20121205_prof.nc
# 20101119_prof.nc  20111128_prof.nc  20121206_prof.nc
# 20101120_prof.nc  20111129_prof.nc  20121207_prof.nc
# 20101121_prof.nc  20111130_prof.nc  20121208_prof.nc
# 20101122_prof.nc  20111201_prof.nc  20121209_prof.nc
# 20101123_prof.nc  20111202_prof.nc  20121210_prof.nc
# 20101124_prof.nc  20111203_prof.nc  20121211_prof.nc
# 20101125_prof.nc  20111204_prof.nc  20121212_prof.nc
# 20101126_prof.nc  20111205_prof.nc  20121213_prof.nc
# 20101127_prof.nc  20111206_prof.nc  20121214_prof.nc
# 20101128_prof.nc  20111207_prof.nc  20121215_prof.nc
# 20101129_prof.nc  20111208_prof.nc  20121216_prof.nc
# 20101130_prof.nc  20111209_prof.nc  20121217_prof.nc
# 20101201_prof.nc  20111210_prof.nc  20121218_prof.nc
# 20101202_prof.nc  20111211_prof.nc  20121219_prof.nc
# 20101203_prof.nc  20111212_prof.nc  20121220_prof.nc
# 20101204_prof.nc  20111213_prof.nc  20121221_prof.nc
# 20101205_prof.nc  20111214_prof.nc  20121222_prof.nc
# 20101206_prof.nc  20111215_prof.nc  20121223_prof.nc
# 20101207_prof.nc  20111216_prof.nc  20121224_prof.nc
# 20101208_prof.nc  20111217_prof.nc  20121225_prof.nc
# 20101209_prof.nc  20111218_prof.nc  20121226_prof.nc
# 20101210_prof.nc  20111219_prof.nc  20121227_prof.nc
# 20101211_prof.nc  20111220_prof.nc  20121228_prof.nc
# 20101212_prof.nc  20111221_prof.nc  20121229_prof.nc
# 20101213_prof.nc  20111222_prof.nc  20121230_prof.nc
# 20101214_prof.nc  20111223_prof.nc  20121231_prof.nc
# 20101215_prof.nc  20111224_prof.nc  EN.4.2.0.f.profiles.g10.201201.nc
# 20101216_prof.nc  20111225_prof.nc  EN.4.2.0.f.profiles.g10.201202.nc
# 20101217_prof.nc  20111226_prof.nc  EN.4.2.0.f.profiles.g10.201203.nc
# 20101218_prof.nc  20111227_prof.nc  EN.4.2.0.f.profiles.g10.201204.nc
# 20101219_prof.nc  20111228_prof.nc  EN.4.2.0.f.profiles.g10.201205.nc
# 20101220_prof.nc  20111229_prof.nc  EN.4.2.0.f.profiles.g10.201206.nc
# 20101221_prof.nc  20111230_prof.nc  EN.4.2.0.f.profiles.g10.201207.nc
# 20101222_prof.nc  20111231_prof.nc  EN.4.2.0.f.profiles.g10.201208.nc
# 20101223_prof.nc  20120101_prof.nc  EN.4.2.0.f.profiles.g10.201209.nc
# 20101224_prof.nc  20120102_prof.nc  EN.4.2.0.f.profiles.g10.201210.nc
# 20101225_prof.nc  20120103_prof.nc  EN.4.2.0.f.profiles.g10.201211.nc
# 20101226_prof.nc  20120104_prof.nc  EN.4.2.0.f.profiles.g10.201212.nc
# 20101227_prof.nc  20120105_prof.nc  EN.4.2.0.f.profiles.g10.201301.nc
# 20101228_prof.nc  20120106_prof.nc  EN.4.2.0.f.profiles.g10.201302.nc
# 20101229_prof.nc  20120107_prof.nc  EN.4.2.0.f.profiles.g10.201303.nc
# 20101230_prof.nc  20120108_prof.nc  EN.4.2.0.f.profiles.g10.201304.nc
# 20101231_prof.nc  20120109_prof.nc  EN.4.2.0.f.profiles.g10.201305.nc
# 20110101_prof.nc  20120110_prof.nc  EN.4.2.0.f.profiles.g10.201306.nc
# 20110102_prof.nc  20120111_prof.nc  EN.4.2.0.f.profiles.g10.201307.nc
# 20110103_prof.nc  20120112_prof.nc  EN.4.2.0.f.profiles.g10.201308.nc
# 20110104_prof.nc  20120113_prof.nc  EN.4.2.0.f.profiles.g10.201309.nc
# 20110105_prof.nc  20120114_prof.nc  EN.4.2.0.f.profiles.g10.201310.nc
# 20110106_prof.nc  20120115_prof.nc  EN.4.2.0.f.profiles.g10.201311.nc
# 20110107_prof.nc  20120116_prof.nc  EN.4.2.0.f.profiles.g10.201312.nc
# 20110108_prof.nc  20120117_prof.nc
# 20110109_prof.nc  20120118_prof.nc

# %%
datemin='2010-01-01'
datemax='2012-12-31'
yearmin=datemin[0:4]
monthmin=datemin[5:7]
yearmax=datemax[0:4]
monthmax=datemax[5:7]

# %%
print(yearmax)
# Out:
# 2012

# %%
        list_filesEN4=[]

# %%
            for m in np.arange(int(monthmin),13):
                mm = "{:02d}".format(m)
                for d in np.arange(1,lday[m]+1):
                    dd = "{:02d}".format(m)
                    list_filesEN4.append(yearmin+str(mm)+str(dd)+'.nc')

# %%
print(list_filesEN4)
# Out:
# ['20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100101.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100202.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100303.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100404.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100505.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100606.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100707.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100808.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909.nc', '20100909 ...

# %%
def select_profiles(latmin,latmax,lonmin,lonmax,datemin,datemax,jsonfile):
        ''' Identify all the EN4 profiles that fall within the selected zone and period
        '''
        lday={1:31,2:28,3:31,4:30,5:31,6:30,7:31,8:31,9:30,10:31,11:30,12:31}
        lday_2012={1:31,2:29,3:31,4:30,5:31,6:30,7:31,8:31,9:30,10:31,11:30,12:31}
        ## Datasets

        #EN4
        diren4="/scratch/cnt0024/hmg2840/albert7a/EN4/"

        yearmin=datemin[0:4]
        monthmin=datemin[5:7]
        yearmax=datemax[0:4]
        monthmax=datemax[5:7]

        list_filesEN4=[]
        if yearmin == yearmax:
            if yearmin == '2012':
                lday=lday_2012
            for m in np.arange(int(monthmin),int(monthmax)+1):
                mm = "{:02d}".format(m)
                for d in np.arange(1,lday[m]+1):
                    dd = "{:02d}".format(d)
                    list_filesEN4.append(yearmin+str(mm)+str(dd)+'_prof.nc')
        else:
            for m in np.arange(int(monthmin),13):
                mm = "{:02d}".format(m)
                for d in np.arange(1,lday[m]+1):
                    dd = "{:02d}".format(d)
                    list_filesEN4.append(yearmin+str(mm)+str(dd)+'_prof.nc')

        if int(yearmin)+1 == int(yearmax):
            if yearmax == '2012':
                lday=lday_2012
                for m in np.arange(1,int(monthmax)+1):
                    mm = "{:02d}".format(m)
                    for d in np.arange(1,lday[m]+1):
                        dd = "{:02d}".format(d)
                        list_filesEN4.append(yearmax+str(mm)+str(dd)+'_prof.nc')
        else:
            for year in np.arange(int(yearmin)+1,int(yearmax)+1):
                if year == 2012:
                    lday=lday_2012
                for m in np.arange(1,13):
                    mm = "{:02d}".format(m)
                    for d in np.arange(1,lday[m]+1):
                        dd = "{:02d}".format(d)
                        list_filesEN4.append(str(year)+str(mm)+str(dd)+'_prof.nc')

        datetmin=pd.to_datetime(datemin)
        datetmax=pd.to_datetime(datemax)
        ttmin=datetime.datetime(int(datetmin.strftime('%Y')),int(datetmin.strftime('%m')),int(datetmin.strftime('%d')),int(datetmin.strftime('%H')),int(datetmin.strftime('%M')))
        ttmax=datetime.datetime(int(datetmax.strftime('%Y')),int(datetmax.strftime('%m')),int(datetmax.strftime('%d')),int(datetmax.strftime('%H')),int(datetmax.strftime('%M')))
        tsecmin=(ttmin-datetime.datetime(1958,1,1,0,0)).total_seconds()
        tsecmax=(ttmax-datetime.datetime(1958,1,1,0,0)).total_seconds()

        for f in np.arange(len(list_filesEN4)):
            fileEN4=list_filesEN4[f]
            print('Processing '+str(fileEN4))
            tfileEN4=diren4+fileEN4
            dsen4=xr.open_dataset(tfileEN4)
            laten4=dsen4['LATITUDE']
            lonen4=dsen4['LONGITUDE']
            dayen4=dsen4['JULD']
            refen4=dsen4['DC_REFERENCE']
            indz=np.where((lonmin<lonen4.values)&(lonen4.values<lonmax)&(latmin<laten4.values)&(laten4.values<latmax))
            prof_zone=[]
            tsecen4z=[]
            for ref in np.arange(len(indz[0])):
                dateen4= pd.to_datetime(str(dayen4[indz[0][ref]].values))
                ten4 = datetime.datetime(int(dateen4.strftime('%Y')),int(dateen4.strftime('%m')),int(dateen4.strftime('%d')),int(dateen4.strftime('%H')),int(dateen4.strftime('%M')))
                tsecen4=(ten4-datetime.datetime(1958,1,1,0,0)).total_seconds()
                if (tsecen4 < tsecmax) & (tsecen4 > tsecmin):
                    prof_zone.append(indz[0][ref])
                    tsecen4z.append(tsecen4)

            for ref in np.arange(len(prof_zone)):
                if 'dictyml' in locals():
                    up={str(refen4[prof_zone[ref]].values):{'reference':str(refen4[prof_zone[ref]].values),'file':fileEN4,'profile no':int(prof_zone[ref]),'latitude':float(laten4[prof_zone[ref]].values),'longitude':float(lonen4[prof_zone[ref]].values),'date':str(dayen4[prof_zone[ref]].values)}}
                    dictyml.update(up)
                else:
                    dictyml={str(refen4[prof_zone[ref]].values):{'reference':str(refen4[prof_zone[ref]].values),'file':fileEN4,'profile no':int(prof_zone[ref]),'latitude':float(laten4[prof_zone[ref]].values),'longitude':float(lonen4[prof_zone[ref]].values),'date':str(dayen4[prof_zone[ref]].values)}}
                    
        with io.open(jsonfile, 'w', encoding='utf8') as outfile:
            outfile.write(str(json.dumps(dictyml, sort_keys=True,indent=4, separators=(',', ': '))))

# %%
select_profiles(latmin,latmax,lonmin,lonmax,datemin,datemax,jsonfile)
# Out:
# 2010
# 2012
# Processing 20100101_prof.nc
# Processing 20100102_prof.nc
# Processing 20100103_prof.nc
# Processing 20100104_prof.nc
# Processing 20100105_prof.nc
# Processing 20100106_prof.nc
# Processing 20100107_prof.nc
# Processing 20100108_prof.nc
# Processing 20100109_prof.nc
# Processing 20100110_prof.nc
# Processing 20100111_prof.nc
# Processing 20100112_prof.nc
# Processing 20100113_prof.nc
# Processing 20100114_prof.nc
# Processing 20100115_prof.nc
# Processing 20100116_prof.nc
# Processing 20100117_prof.nc
# Processing 20100118_prof.nc
# Processing 20100119_prof.nc
# Processing 20100120_prof.nc
# Processing 20100121_prof.nc
# Processing 20100122_prof.nc
# Processing 20100123_prof.nc
# Processing 20100124_prof.nc
# Processing 20100125_prof.nc
# Processing 20100126_prof.nc
# Processing 20100127_prof.nc
# Processing 20100128_prof.nc
# Processing 20100129_prof.nc
# Processing 20100130_prof.nc
# Processing 20100131_prof.nc
# Processing 20100201_prof.nc
# Processing 20100202_prof.nc
# Processing 20100203_prof.nc
# Processing 20100204_prof.nc
# Processing 20100205_prof.nc
# Processing 20100206_prof.nc
# Processing 20100207_prof.nc
# Processing 20100208_prof.nc
# Processing 20100209_prof.nc
# Processing 20100210_prof.nc
# Processing 20100211_prof.nc
# Processing 20100212_prof.nc
# Processing 20100213_prof.nc
# Processing 20100214_prof.nc
# Processing 20100215_prof.nc
# Processing 20100216_prof.nc
# Processing 20100217_prof.nc
# Processing 20100218_prof.nc
# Processing 20100219_prof.nc
# Processing 20100220_prof.nc
# Processing 20100221_prof.nc
# Processing 20100222_prof.nc
# Processing 20100223_prof.nc
# Processing 20100224_prof.nc
# Processing 20100225_prof.nc
# Processing 20100226_prof.nc
# Processing 20100227_prof.nc
# Processing 20100228_prof.nc
# Processing 20100301_prof.nc
# Processing 20100302_prof.nc
# Processing 20100303_prof.nc
# Processing 20100304_prof.nc
# Processing 20100305_prof.nc
# Processing 20100306_prof.nc
# Processing 20100307_prof.nc
# Processing 20100308_prof.nc
# Processing 20100309_prof.nc
# Processing 20100310_prof.nc
# Processing 20100311_prof.nc
# Processing 20100312_prof.nc
# Processing 20100313_prof.nc
# Processing 20100314_prof.nc
# Processing 20100315_prof.nc
# Processing 20100316_prof.nc
# Processing 20100317_prof.nc
# Processing 20100318_prof.nc
# Processing 20100319_prof.nc
# Processing 20100320_prof.nc
# Processing 20100321_prof.nc
# Processing 20100322_prof.nc
# Processing 20100323_prof.nc
# Processing 20100324_prof.nc
# Processing 20100325_prof.nc
# Processing 20100326_prof.nc
# Processing 20100327_prof.nc
# Processing 20100328_prof.nc
# Processing 20100329_prof.nc
# Processing 20100330_prof.nc
# Processing 20100331_prof.nc
# Processing 20100401_prof.nc
# Processing 20100402_prof.nc
# Processing 20100403_prof.nc
# Processing 20100404_prof.nc
# Processing 20100405_prof.nc
# Processing 20100406_prof.nc
# Processing 20100407_prof.nc
# Processing 20100408_prof.nc
# Processing 20100409_prof.nc
# Processing 20100410_prof.nc
# Processing 20100411_prof.nc
# Processing 20100412_prof.nc
# Processing 20100413_prof.nc
# Processing 20100414_prof.nc
# Processing 20100415_prof.nc
# Processing 20100416_prof.nc
# Processing 20100417_prof.nc
# Processing 20100418_prof.nc
# Processing 20100419_prof.nc
# Processing 20100420_prof.nc
# Processing 20100421_prof.nc
# Processing 20100422_prof.nc
# Processing 20100423_prof.nc
# Processing 20100424_prof.nc
# Processing 20100425_prof.nc
# Processing 20100426_prof.nc
# Processing 20100427_prof.nc
# Processing 20100428_prof.nc
# Processing 20100429_prof.nc
# Processing 20100430_prof.nc
# Processing 20100501_prof.nc
# Processing 20100502_prof.nc
# Processing 20100503_prof.nc
# Processing 20100504_prof.nc
# Processing 20100505_prof.nc
# Processing 20100506_prof.nc
# Processing 20100507_prof.nc
# Processing 20100508_prof.nc
# Processing 20100509_prof.nc
# Processing 20100510_prof.nc
# Processing 20100511_prof.nc
# Processing 20100512_prof.nc
# Processing 20100513_prof.nc
# Processing 20100514_prof.nc
# Processing 20100515_prof.nc
# Processing 20100516_prof.nc
# Processing 20100517_prof.nc
# Processing 20100518_prof.nc
# Processing 20100519_prof.nc
# Processing 20100520_prof.nc
# Processing 20100521_prof.nc
# Processing 20100522_prof.nc
# Processing 20100523_prof.nc
# Processing 20100524_prof.nc
# Processing 20100525_prof.nc
# Processing 20100526_prof.nc
# Processing 20100527_prof.nc
# Processing 20100528_prof.nc
# Processing 20100529_prof.nc
# Processing 20100530_prof.nc
# Processing 20100531_prof.nc
# Processing 20100601_prof.nc
# Processing 20100602_prof.nc
# Processing 20100603_prof.nc
# Processing 20100604_prof.nc
# Processing 20100605_prof.nc
# Processing 20100606_prof.nc
# Processing 20100607_prof.nc
# Processing 20100608_prof.nc
# Processing 20100609_prof.nc
# Processing 20100610_prof.nc
# Processing 20100611_prof.nc
# Processing 20100612_prof.nc
# Processing 20100613_prof.nc
# Processing 20100614_prof.nc
# Processing 20100615_prof.nc
# Processing 20100616_prof.nc
# Processing 20100617_prof.nc
# Processing 20100618_prof.nc
# Processing 20100619_prof.nc
# Processing 20100620_prof.nc
# Processing 20100621_prof.nc
# Processing 20100622_prof.nc
# Processing 20100623_prof.nc
# Processing 20100624_prof.nc
# Processing 20100625_prof.nc
# Processing 20100626_prof.nc
# Processing 20100627_prof.nc
# Processing 20100628_prof.nc
# Processing 20100629_prof.nc
# Processing 20100630_prof.nc
# Processing 20100701_prof.nc
# Processing 20100702_prof.nc
# Processing 20100703_prof.nc
# Processing 20100704_prof.nc
# Processing 20100705_prof.nc
# Processing 20100706_prof.nc
# Processing 20100707_prof.nc
# Processing 20100708_prof.nc
# Processing 20100709_prof.nc
# Processing 20100710_prof.nc
# Processing 20100711_prof.nc
# Processing 20100712_prof.nc
# Processing 20100713_prof.nc
# Processing 20100714_prof.nc
# Processing 20100715_prof.nc
# Processing 20100716_prof.nc
# Processing 20100717_prof.nc
# Processing 20100718_prof.nc
# Processing 20100719_prof.nc
# Processing 20100720_prof.nc
# Processing 20100721_prof.nc
# Processing 20100722_prof.nc
# Processing 20100723_prof.nc
# Processing 20100724_prof.nc
# Processing 20100725_prof.nc
# Processing 20100726_prof.nc
# Processing 20100727_prof.nc
# Processing 20100728_prof.nc
# Processing 20100729_prof.nc
# Processing 20100730_prof.nc
# Processing 20100731_prof.nc
# Processing 20100801_prof.nc
# Processing 20100802_prof.nc
# Processing 20100803_prof.nc
# Processing 20100804_prof.nc
# Processing 20100805_prof.nc
# Processing 20100806_prof.nc
# Processing 20100807_prof.nc
# Processing 20100808_prof.nc
# Processing 20100809_prof.nc
# Processing 20100810_prof.nc
# Processing 20100811_prof.nc
# Processing 20100812_prof.nc
# Processing 20100813_prof.nc
# Processing 20100814_prof.nc
# Processing 20100815_prof.nc
# Processing 20100816_prof.nc
# Processing 20100817_prof.nc
# Processing 20100818_prof.nc
# Processing 20100819_prof.nc
# Processing 20100820_prof.nc
# Processing 20100821_prof.nc
# Processing 20100822_prof.nc
# Processing 20100823_prof.nc
# Processing 20100824_prof.nc
# Processing 20100825_prof.nc
# Processing 20100826_prof.nc
# Processing 20100827_prof.nc
# Processing 20100828_prof.nc
# Processing 20100829_prof.nc
# Processing 20100830_prof.nc
# Processing 20100831_prof.nc
# Processing 20100901_prof.nc
# Processing 20100902_prof.nc
# Processing 20100903_prof.nc
# Processing 20100904_prof.nc
# Processing 20100905_prof.nc
# Processing 20100906_prof.nc
# Processing 20100907_prof.nc
# Processing 20100908_prof.nc
# Processing 20100909_prof.nc
# Processing 20100910_prof.nc
# Processing 20100911_prof.nc
# Processing 20100912_prof.nc
# Processing 20100913_prof.nc
# Processing 20100914_prof.nc
# Processing 20100915_prof.nc
# Processing 20100916_prof.nc
# Processing 20100917_prof.nc
# Processing 20100918_prof.nc
# Processing 20100919_prof.nc
# Processing 20100920_prof.nc
# Processing 20100921_prof.nc
# Processing 20100922_prof.nc
# Processing 20100923_prof.nc
# Processing 20100924_prof.nc
# Processing 20100925_prof.nc
# Processing 20100926_prof.nc
# Processing 20100927_prof.nc
# Processing 20100928_prof.nc
# Processing 20100929_prof.nc
# Processing 20100930_prof.nc
# Processing 20101001_prof.nc
# Processing 20101002_prof.nc
# Processing 20101003_prof.nc
# Processing 20101004_prof.nc
# Processing 20101005_prof.nc
# Processing 20101006_prof.nc
# Processing 20101007_prof.nc
# Processing 20101008_prof.nc
# Processing 20101009_prof.nc
# Processing 20101010_prof.nc
# Processing 20101011_prof.nc
# Processing 20101012_prof.nc
# Processing 20101013_prof.nc
# Processing 20101014_prof.nc
# Processing 20101015_prof.nc
# Processing 20101016_prof.nc
# Processing 20101017_prof.nc
# Processing 20101018_prof.nc
# Processing 20101019_prof.nc
# Processing 20101020_prof.nc
# Processing 20101021_prof.nc
# Processing 20101022_prof.nc
# Processing 20101023_prof.nc
# Processing 20101024_prof.nc
# Processing 20101025_prof.nc
# Processing 20101026_prof.nc
# Processing 20101027_prof.nc
# Processing 20101028_prof.nc
# Processing 20101029_prof.nc
# Processing 20101030_prof.nc
# Processing 20101031_prof.nc
# Processing 20101101_prof.nc
# Processing 20101102_prof.nc
# Processing 20101103_prof.nc
# Processing 20101104_prof.nc
# Processing 20101105_prof.nc
# Processing 20101106_prof.nc
# Processing 20101107_prof.nc
# Processing 20101108_prof.nc
# Processing 20101109_prof.nc
# Processing 20101110_prof.nc
# Processing 20101111_prof.nc
# Processing 20101112_prof.nc
# Processing 20101113_prof.nc
# Processing 20101114_prof.nc
# Processing 20101115_prof.nc
# Processing 20101116_prof.nc
# Processing 20101117_prof.nc
# Processing 20101118_prof.nc
# Processing 20101119_prof.nc
# Processing 20101120_prof.nc
# Processing 20101121_prof.nc
# Processing 20101122_prof.nc
# Processing 20101123_prof.nc
# Processing 20101124_prof.nc
# Processing 20101125_prof.nc
# Processing 20101126_prof.nc
# Processing 20101127_prof.nc
# Processing 20101128_prof.nc
# Processing 20101129_prof.nc
# Processing 20101130_prof.nc
# Processing 20101201_prof.nc
# Processing 20101202_prof.nc
# Processing 20101203_prof.nc
# Processing 20101204_prof.nc
# Processing 20101205_prof.nc
# Processing 20101206_prof.nc
# Processing 20101207_prof.nc
# Processing 20101208_prof.nc
# Processing 20101209_prof.nc
# Processing 20101210_prof.nc
# Processing 20101211_prof.nc
# Processing 20101212_prof.nc
# Processing 20101213_prof.nc
# Processing 20101214_prof.nc
# Processing 20101215_prof.nc
# Processing 20101216_prof.nc
# Processing 20101217_prof.nc
# Processing 20101218_prof.nc
# Processing 20101219_prof.nc
# Processing 20101220_prof.nc
# Processing 20101221_prof.nc
# Processing 20101222_prof.nc
# Processing 20101223_prof.nc
# Processing 20101224_prof.nc
# Processing 20101225_prof.nc
# Processing 20101226_prof.nc
# Processing 20101227_prof.nc
# Processing 20101228_prof.nc
# Processing 20101229_prof.nc
# Processing 20101230_prof.nc
# Processing 20101231_prof.nc
# Processing 20110101_prof.nc
# Processing 20110102_prof.nc
# Processing 20110103_prof.nc
# Processing 20110104_prof.nc
# Processing 20110105_prof.nc
# Processing 20110106_prof.nc
# Processing 20110107_prof.nc
# Processing 20110108_prof.nc
# Processing 20110109_prof.nc
# Processing 20110110_prof.nc
# Processing 20110111_prof.nc
# Processing 20110112_prof.nc
# Processing 20110113_prof.nc
# Processing 20110114_prof.nc
# Processing 20110115_prof.nc
# Processing 20110116_prof.nc
# Processing 20110117_prof.nc
# Processing 20110118_prof.nc
# Processing 20110119_prof.nc
# Processing 20110120_prof.nc
# Processing 20110121_prof.nc
# Processing 20110122_prof.nc
# Processing 20110123_prof.nc
# Processing 20110124_prof.nc
# Processing 20110125_prof.nc
# Processing 20110126_prof.nc
# Processing 20110127_prof.nc
# Processing 20110128_prof.nc
# Processing 20110129_prof.nc
# Processing 20110130_prof.nc
# Processing 20110131_prof.nc
# Processing 20110201_prof.nc
# Processing 20110202_prof.nc
# Processing 20110203_prof.nc
# Processing 20110204_prof.nc
# Processing 20110205_prof.nc
# Processing 20110206_prof.nc
# Processing 20110207_prof.nc
# Processing 20110208_prof.nc
# Processing 20110209_prof.nc
# Processing 20110210_prof.nc
# Processing 20110211_prof.nc
# Processing 20110212_prof.nc
# Processing 20110213_prof.nc
# Processing 20110214_prof.nc
# Processing 20110215_prof.nc
# Processing 20110216_prof.nc
# Processing 20110217_prof.nc
# Processing 20110218_prof.nc
# Processing 20110219_prof.nc
# Processing 20110220_prof.nc
# Processing 20110221_prof.nc
# Processing 20110222_prof.nc
# Processing 20110223_prof.nc
# Processing 20110224_prof.nc
# Processing 20110225_prof.nc
# Processing 20110226_prof.nc
# Processing 20110227_prof.nc
# Processing 20110228_prof.nc
# Processing 20110301_prof.nc
# Processing 20110302_prof.nc
# Processing 20110303_prof.nc
# Processing 20110304_prof.nc
# Processing 20110305_prof.nc
# Processing 20110306_prof.nc
# Processing 20110307_prof.nc
# Processing 20110308_prof.nc
# Processing 20110309_prof.nc
# Processing 20110310_prof.nc
# Processing 20110311_prof.nc
# Processing 20110312_prof.nc
# Processing 20110313_prof.nc
# Processing 20110314_prof.nc
# Processing 20110315_prof.nc
# Processing 20110316_prof.nc
# Processing 20110317_prof.nc
# Processing 20110318_prof.nc
# Processing 20110319_prof.nc
# Processing 20110320_prof.nc
# Processing 20110321_prof.nc
# Processing 20110322_prof.nc
# Processing 20110323_prof.nc
# Processing 20110324_prof.nc
# Processing 20110325_prof.nc
# Processing 20110326_prof.nc
# Processing 20110327_prof.nc
# Processing 20110328_prof.nc
# Processing 20110329_prof.nc
# Processing 20110330_prof.nc
# Processing 20110331_prof.nc
# Processing 20110401_prof.nc
# Processing 20110402_prof.nc
# Processing 20110403_prof.nc
# Processing 20110404_prof.nc
# Processing 20110405_prof.nc
# Processing 20110406_prof.nc
# Processing 20110407_prof.nc
# Processing 20110408_prof.nc
# Processing 20110409_prof.nc
# Processing 20110410_prof.nc
# Processing 20110411_prof.nc
# Processing 20110412_prof.nc
# Processing 20110413_prof.nc
# Processing 20110414_prof.nc
# Processing 20110415_prof.nc
# Processing 20110416_prof.nc
# Processing 20110417_prof.nc
# Processing 20110418_prof.nc
# Processing 20110419_prof.nc
# Processing 20110420_prof.nc
# Processing 20110421_prof.nc
# Processing 20110422_prof.nc
# Processing 20110423_prof.nc
# Processing 20110424_prof.nc
# Processing 20110425_prof.nc
# Processing 20110426_prof.nc
# Processing 20110427_prof.nc
# Processing 20110428_prof.nc
# Processing 20110429_prof.nc
# Processing 20110430_prof.nc
# Processing 20110501_prof.nc
# Processing 20110502_prof.nc
# Processing 20110503_prof.nc
# Processing 20110504_prof.nc
# Processing 20110505_prof.nc
# Processing 20110506_prof.nc
# Processing 20110507_prof.nc
# Processing 20110508_prof.nc
# Processing 20110509_prof.nc
# Processing 20110510_prof.nc
# Processing 20110511_prof.nc
# Processing 20110512_prof.nc
# Processing 20110513_prof.nc
# Processing 20110514_prof.nc
# Processing 20110515_prof.nc
# Processing 20110516_prof.nc
# Processing 20110517_prof.nc
# Processing 20110518_prof.nc
# Processing 20110519_prof.nc
# Processing 20110520_prof.nc
# Processing 20110521_prof.nc
# Processing 20110522_prof.nc
# Processing 20110523_prof.nc
# Processing 20110524_prof.nc
# Processing 20110525_prof.nc
# Processing 20110526_prof.nc
# Processing 20110527_prof.nc
# Processing 20110528_prof.nc
# Processing 20110529_prof.nc
# Processing 20110530_prof.nc
# Processing 20110531_prof.nc
# Processing 20110601_prof.nc
# Processing 20110602_prof.nc
# Processing 20110603_prof.nc
# Processing 20110604_prof.nc
# Processing 20110605_prof.nc
# Processing 20110606_prof.nc
# Processing 20110607_prof.nc
# Processing 20110608_prof.nc
# Processing 20110609_prof.nc
# Processing 20110610_prof.nc
# Processing 20110611_prof.nc
# Processing 20110612_prof.nc
# Processing 20110613_prof.nc
# Processing 20110614_prof.nc
# Processing 20110615_prof.nc
# Processing 20110616_prof.nc
# Processing 20110617_prof.nc
# Processing 20110618_prof.nc
# Processing 20110619_prof.nc
# Processing 20110620_prof.nc
# Processing 20110621_prof.nc
# Processing 20110622_prof.nc
# Processing 20110623_prof.nc
# Processing 20110624_prof.nc
# Processing 20110625_prof.nc
# Processing 20110626_prof.nc
# Processing 20110627_prof.nc
# Processing 20110628_prof.nc
# Processing 20110629_prof.nc
# Processing 20110630_prof.nc
# Processing 20110701_prof.nc
# Processing 20110702_prof.nc
# Processing 20110703_prof.nc
# Processing 20110704_prof.nc
# Processing 20110705_prof.nc
# Processing 20110706_prof.nc
# Processing 20110707_prof.nc
# Processing 20110708_prof.nc
# Processing 20110709_prof.nc
# Processing 20110710_prof.nc
# Processing 20110711_prof.nc
# Processing 20110712_prof.nc
# Processing 20110713_prof.nc
# Processing 20110714_prof.nc
# Processing 20110715_prof.nc
# Processing 20110716_prof.nc
# Processing 20110717_prof.nc
# Processing 20110718_prof.nc
# Processing 20110719_prof.nc
# Processing 20110720_prof.nc
# Processing 20110721_prof.nc
# Processing 20110722_prof.nc
# Processing 20110723_prof.nc
# Processing 20110724_prof.nc
# Processing 20110725_prof.nc
# Processing 20110726_prof.nc
# Processing 20110727_prof.nc
# Processing 20110728_prof.nc
# Processing 20110729_prof.nc
# Processing 20110730_prof.nc
# Processing 20110731_prof.nc
# Processing 20110801_prof.nc
# Processing 20110802_prof.nc
# Processing 20110803_prof.nc
# Processing 20110804_prof.nc
# Processing 20110805_prof.nc
# Processing 20110806_prof.nc
# Processing 20110807_prof.nc
# Processing 20110808_prof.nc
# Processing 20110809_prof.nc
# Processing 20110810_prof.nc
# Processing 20110811_prof.nc
# Processing 20110812_prof.nc
# Processing 20110813_prof.nc
# Processing 20110814_prof.nc
# Processing 20110815_prof.nc
# Processing 20110816_prof.nc
# Processing 20110817_prof.nc
# Processing 20110818_prof.nc
# Processing 20110819_prof.nc
# Processing 20110820_prof.nc
# Processing 20110821_prof.nc
# Processing 20110822_prof.nc
# Processing 20110823_prof.nc
# Processing 20110824_prof.nc
# Processing 20110825_prof.nc
# Processing 20110826_prof.nc
# Processing 20110827_prof.nc
# Processing 20110828_prof.nc
# Processing 20110829_prof.nc
# Processing 20110830_prof.nc
# Processing 20110831_prof.nc
# Processing 20110901_prof.nc
# Processing 20110902_prof.nc
# Processing 20110903_prof.nc
# Processing 20110904_prof.nc
# Processing 20110905_prof.nc
# Processing 20110906_prof.nc
# Processing 20110907_prof.nc
# Processing 20110908_prof.nc
# Processing 20110909_prof.nc
# Processing 20110910_prof.nc
# Processing 20110911_prof.nc
# Processing 20110912_prof.nc
# Processing 20110913_prof.nc
# Processing 20110914_prof.nc
# Processing 20110915_prof.nc
# Processing 20110916_prof.nc
# Processing 20110917_prof.nc
# Processing 20110918_prof.nc
# Processing 20110919_prof.nc
# Processing 20110920_prof.nc
# Processing 20110921_prof.nc
# Processing 20110922_prof.nc
# Processing 20110923_prof.nc
# Processing 20110924_prof.nc
# Processing 20110925_prof.nc
# Processing 20110926_prof.nc
# Processing 20110927_prof.nc
# Processing 20110928_prof.nc
# Processing 20110929_prof.nc
# Processing 20110930_prof.nc
# Processing 20111001_prof.nc
# Processing 20111002_prof.nc
# Processing 20111003_prof.nc
# Processing 20111004_prof.nc
# Processing 20111005_prof.nc
# Processing 20111006_prof.nc
# Processing 20111007_prof.nc
# Processing 20111008_prof.nc
# Processing 20111009_prof.nc
# Processing 20111010_prof.nc
# Processing 20111011_prof.nc
# Processing 20111012_prof.nc
# Processing 20111013_prof.nc
# Processing 20111014_prof.nc
# Processing 20111015_prof.nc
# Processing 20111016_prof.nc
# Processing 20111017_prof.nc
# Processing 20111018_prof.nc
# Processing 20111019_prof.nc
# Processing 20111020_prof.nc
# Processing 20111021_prof.nc
# Processing 20111022_prof.nc
# Processing 20111023_prof.nc
# Processing 20111024_prof.nc
# Processing 20111025_prof.nc
# Processing 20111026_prof.nc
# Processing 20111027_prof.nc
# Processing 20111028_prof.nc
# Processing 20111029_prof.nc
# Processing 20111030_prof.nc
# Processing 20111031_prof.nc
# Processing 20111101_prof.nc
# Processing 20111102_prof.nc
# Processing 20111103_prof.nc
# Processing 20111104_prof.nc
# Processing 20111105_prof.nc
# Processing 20111106_prof.nc
# Processing 20111107_prof.nc
# Processing 20111108_prof.nc
# Processing 20111109_prof.nc
# Processing 20111110_prof.nc
# Processing 20111111_prof.nc
# Processing 20111112_prof.nc
# Processing 20111113_prof.nc
# Processing 20111114_prof.nc
# Processing 20111115_prof.nc
# Processing 20111116_prof.nc
# Processing 20111117_prof.nc
# Processing 20111118_prof.nc
# Processing 20111119_prof.nc
# Processing 20111120_prof.nc
# Processing 20111121_prof.nc
# Processing 20111122_prof.nc
# Processing 20111123_prof.nc
# Processing 20111124_prof.nc
# Processing 20111125_prof.nc
# Processing 20111126_prof.nc
# Processing 20111127_prof.nc
# Processing 20111128_prof.nc
# Processing 20111129_prof.nc
# Processing 20111130_prof.nc
# Processing 20111201_prof.nc
# Processing 20111202_prof.nc
# Processing 20111203_prof.nc
# Processing 20111204_prof.nc
# Processing 20111205_prof.nc
# Processing 20111206_prof.nc
# Processing 20111207_prof.nc
# Processing 20111208_prof.nc
# Processing 20111209_prof.nc
# Processing 20111210_prof.nc
# Processing 20111211_prof.nc
# Processing 20111212_prof.nc
# Processing 20111213_prof.nc
# Processing 20111214_prof.nc
# Processing 20111215_prof.nc
# Processing 20111216_prof.nc
# Processing 20111217_prof.nc
# Processing 20111218_prof.nc
# Processing 20111219_prof.nc
# Processing 20111220_prof.nc
# Processing 20111221_prof.nc
# Processing 20111222_prof.nc
# Processing 20111223_prof.nc
# Processing 20111224_prof.nc
# Processing 20111225_prof.nc
# Processing 20111226_prof.nc
# Processing 20111227_prof.nc
# Processing 20111228_prof.nc
# Processing 20111229_prof.nc
# Processing 20111230_prof.nc
# Processing 20111231_prof.nc
# Processing 20120101_prof.nc
# Processing 20120102_prof.nc
# Processing 20120103_prof.nc
# Processing 20120104_prof.nc
# Processing 20120105_prof.nc
# Processing 20120106_prof.nc
# Processing 20120107_prof.nc
# Processing 20120108_prof.nc
# Processing 20120109_prof.nc
# Processing 20120110_prof.nc
# Processing 20120111_prof.nc
# Processing 20120112_prof.nc
# Processing 20120113_prof.nc
# Processing 20120114_prof.nc
# Processing 20120115_prof.nc
# Processing 20120116_prof.nc
# Processing 20120117_prof.nc
# Processing 20120118_prof.nc
# Processing 20120119_prof.nc
# Processing 20120120_prof.nc
# Processing 20120121_prof.nc
# Processing 20120122_prof.nc
# Processing 20120123_prof.nc
# Processing 20120124_prof.nc
# Processing 20120125_prof.nc
# Processing 20120126_prof.nc
# Processing 20120127_prof.nc
# Processing 20120128_prof.nc
# Processing 20120129_prof.nc
# Processing 20120130_prof.nc
# Processing 20120131_prof.nc
# Processing 20120201_prof.nc
# Processing 20120202_prof.nc
# Processing 20120203_prof.nc
# Processing 20120204_prof.nc
# Processing 20120205_prof.nc
# Processing 20120206_prof.nc
# Processing 20120207_prof.nc
# Processing 20120208_prof.nc
# Processing 20120209_prof.nc
# Processing 20120210_prof.nc
# Processing 20120211_prof.nc
# Processing 20120212_prof.nc
# Processing 20120213_prof.nc
# Processing 20120214_prof.nc
# Processing 20120215_prof.nc
# Processing 20120216_prof.nc
# Processing 20120217_prof.nc
# Processing 20120218_prof.nc
# Processing 20120219_prof.nc
# Processing 20120220_prof.nc
# Processing 20120221_prof.nc
# Processing 20120222_prof.nc
# Processing 20120223_prof.nc
# Processing 20120224_prof.nc
# Processing 20120225_prof.nc
# Processing 20120226_prof.nc
# Processing 20120227_prof.nc
# Processing 20120228_prof.nc
# Processing 20120229_prof.nc
# Processing 20120301_prof.nc
# Processing 20120302_prof.nc
# Processing 20120303_prof.nc
# Processing 20120304_prof.nc
# Processing 20120305_prof.nc
# Processing 20120306_prof.nc
# Processing 20120307_prof.nc
# Processing 20120308_prof.nc
# Processing 20120309_prof.nc
# Processing 20120310_prof.nc
# Processing 20120311_prof.nc
# Processing 20120312_prof.nc
# Processing 20120313_prof.nc
# Processing 20120314_prof.nc
# Processing 20120315_prof.nc
# Processing 20120316_prof.nc
# Processing 20120317_prof.nc
# Processing 20120318_prof.nc
# Processing 20120319_prof.nc
# Processing 20120320_prof.nc
# Processing 20120321_prof.nc
# Processing 20120322_prof.nc
# Processing 20120323_prof.nc
# Processing 20120324_prof.nc
# Processing 20120325_prof.nc
# Processing 20120326_prof.nc
# Processing 20120327_prof.nc
# Processing 20120328_prof.nc
# Processing 20120329_prof.nc
# Processing 20120330_prof.nc
# Processing 20120331_prof.nc
# Processing 20120401_prof.nc
# Processing 20120402_prof.nc
# Processing 20120403_prof.nc
# Processing 20120404_prof.nc
# Processing 20120405_prof.nc
# Processing 20120406_prof.nc
# Processing 20120407_prof.nc
# Processing 20120408_prof.nc
# Processing 20120409_prof.nc
# Processing 20120410_prof.nc
# Processing 20120411_prof.nc
# Processing 20120412_prof.nc
# Processing 20120413_prof.nc
# Processing 20120414_prof.nc
# Processing 20120415_prof.nc
# Processing 20120416_prof.nc
# Processing 20120417_prof.nc
# Processing 20120418_prof.nc
# Processing 20120419_prof.nc
# Processing 20120420_prof.nc
# Processing 20120421_prof.nc
# Processing 20120422_prof.nc
# Processing 20120423_prof.nc
# Processing 20120424_prof.nc
# Processing 20120425_prof.nc
# Processing 20120426_prof.nc
# Processing 20120427_prof.nc
# Processing 20120428_prof.nc
# Processing 20120429_prof.nc
# Processing 20120430_prof.nc
# Processing 20120501_prof.nc
# Processing 20120502_prof.nc
# Processing 20120503_prof.nc
# Processing 20120504_prof.nc
# Processing 20120505_prof.nc
# Processing 20120506_prof.nc
# Processing 20120507_prof.nc
# Processing 20120508_prof.nc
# Processing 20120509_prof.nc
# Processing 20120510_prof.nc
# Processing 20120511_prof.nc
# Processing 20120512_prof.nc
# Processing 20120513_prof.nc
# Processing 20120514_prof.nc
# Processing 20120515_prof.nc
# Processing 20120516_prof.nc
# Processing 20120517_prof.nc
# Processing 20120518_prof.nc
# Processing 20120519_prof.nc
# Processing 20120520_prof.nc
# Processing 20120521_prof.nc
# Processing 20120522_prof.nc
# Processing 20120523_prof.nc
# Processing 20120524_prof.nc
# Processing 20120525_prof.nc
# Processing 20120526_prof.nc
# Processing 20120527_prof.nc
# Processing 20120528_prof.nc
# Processing 20120529_prof.nc
# Processing 20120530_prof.nc
# Processing 20120531_prof.nc
# Processing 20120601_prof.nc
# Processing 20120602_prof.nc
# Processing 20120603_prof.nc
# Processing 20120604_prof.nc
# Processing 20120605_prof.nc
# Processing 20120606_prof.nc
# Processing 20120607_prof.nc
# Processing 20120608_prof.nc
# Processing 20120609_prof.nc
# Processing 20120610_prof.nc
# Processing 20120611_prof.nc
# Processing 20120612_prof.nc
# Processing 20120613_prof.nc
# Processing 20120614_prof.nc
# Processing 20120615_prof.nc
# Processing 20120616_prof.nc
# Processing 20120617_prof.nc
# Processing 20120618_prof.nc
# Processing 20120619_prof.nc
# Processing 20120620_prof.nc
# Processing 20120621_prof.nc
# Processing 20120622_prof.nc
# Processing 20120623_prof.nc
# Processing 20120624_prof.nc
# Processing 20120625_prof.nc
# Processing 20120626_prof.nc
# Processing 20120627_prof.nc
# Processing 20120628_prof.nc
# Processing 20120629_prof.nc
# Processing 20120630_prof.nc
# Processing 20120701_prof.nc
# Processing 20120702_prof.nc
# Processing 20120703_prof.nc
# Processing 20120704_prof.nc
# Processing 20120705_prof.nc
# Processing 20120706_prof.nc
# Processing 20120707_prof.nc
# Processing 20120708_prof.nc
# Processing 20120709_prof.nc
# Processing 20120710_prof.nc
# Processing 20120711_prof.nc
# Processing 20120712_prof.nc
# Processing 20120713_prof.nc
# Processing 20120714_prof.nc
# Processing 20120715_prof.nc
# Processing 20120716_prof.nc
# Processing 20120717_prof.nc
# Processing 20120718_prof.nc
# Processing 20120719_prof.nc
# Processing 20120720_prof.nc
# Processing 20120721_prof.nc
# Processing 20120722_prof.nc
# Processing 20120723_prof.nc
# Processing 20120724_prof.nc
# Processing 20120725_prof.nc
# Processing 20120726_prof.nc
# Processing 20120727_prof.nc
# Processing 20120728_prof.nc
# Processing 20120729_prof.nc
# Processing 20120730_prof.nc
# Processing 20120731_prof.nc
# Processing 20120801_prof.nc
# Processing 20120802_prof.nc
# Processing 20120803_prof.nc
# Processing 20120804_prof.nc
# Processing 20120805_prof.nc
# Processing 20120806_prof.nc
# Processing 20120807_prof.nc
# Processing 20120808_prof.nc
# Processing 20120809_prof.nc
# Processing 20120810_prof.nc
# Processing 20120811_prof.nc
# Processing 20120812_prof.nc
# Processing 20120813_prof.nc
# Processing 20120814_prof.nc
# Processing 20120815_prof.nc
# Processing 20120816_prof.nc
# Processing 20120817_prof.nc
# Processing 20120818_prof.nc
# Processing 20120819_prof.nc
# Processing 20120820_prof.nc
# Processing 20120821_prof.nc
# Processing 20120822_prof.nc
# Processing 20120823_prof.nc
# Processing 20120824_prof.nc
# Processing 20120825_prof.nc
# Processing 20120826_prof.nc
# Processing 20120827_prof.nc
# Processing 20120828_prof.nc
# Processing 20120829_prof.nc
# Processing 20120830_prof.nc
# Processing 20120831_prof.nc
# Processing 20120901_prof.nc
# Processing 20120902_prof.nc
# Processing 20120903_prof.nc
# Processing 20120904_prof.nc
# Processing 20120905_prof.nc
# Processing 20120906_prof.nc
# Processing 20120907_prof.nc
# Processing 20120908_prof.nc
# Processing 20120909_prof.nc
# Processing 20120910_prof.nc
# Processing 20120911_prof.nc
# Processing 20120912_prof.nc
# Processing 20120913_prof.nc
# Processing 20120914_prof.nc
# Processing 20120915_prof.nc
# Processing 20120916_prof.nc
# Processing 20120917_prof.nc
# Processing 20120918_prof.nc
# Processing 20120919_prof.nc
# Processing 20120920_prof.nc
# Processing 20120921_prof.nc
# Processing 20120922_prof.nc
# Processing 20120923_prof.nc
# Processing 20120924_prof.nc
# Processing 20120925_prof.nc
# Processing 20120926_prof.nc
# Processing 20120927_prof.nc
# Processing 20120928_prof.nc
# Processing 20120929_prof.nc
# Processing 20120930_prof.nc
# Processing 20121001_prof.nc
# Processing 20121002_prof.nc
# Processing 20121003_prof.nc
# Processing 20121004_prof.nc
# Processing 20121005_prof.nc
# Processing 20121006_prof.nc
# Processing 20121007_prof.nc
# Processing 20121008_prof.nc
# Processing 20121009_prof.nc
# Processing 20121010_prof.nc
# Processing 20121011_prof.nc
# Processing 20121012_prof.nc
# Processing 20121013_prof.nc
# Processing 20121014_prof.nc
# Processing 20121015_prof.nc
# Processing 20121016_prof.nc
# Processing 20121017_prof.nc
# Processing 20121018_prof.nc
# Processing 20121019_prof.nc
# Processing 20121020_prof.nc
# Processing 20121021_prof.nc
# Processing 20121022_prof.nc
# Processing 20121023_prof.nc
# Processing 20121024_prof.nc
# Processing 20121025_prof.nc
# Processing 20121026_prof.nc
# Processing 20121027_prof.nc
# Processing 20121028_prof.nc
# Processing 20121029_prof.nc
# Processing 20121030_prof.nc
# Processing 20121031_prof.nc
# Processing 20121101_prof.nc
# Processing 20121102_prof.nc
# Processing 20121103_prof.nc
# Processing 20121104_prof.nc
# Processing 20121105_prof.nc
# Processing 20121106_prof.nc
# Processing 20121107_prof.nc
# Processing 20121108_prof.nc
# Processing 20121109_prof.nc
# Processing 20121110_prof.nc
# Processing 20121111_prof.nc
# Processing 20121112_prof.nc
# Processing 20121113_prof.nc
# Processing 20121114_prof.nc
# Processing 20121115_prof.nc
# Processing 20121116_prof.nc
# Processing 20121117_prof.nc
# Processing 20121118_prof.nc
# Processing 20121119_prof.nc
# Processing 20121120_prof.nc
# Processing 20121121_prof.nc
# Processing 20121122_prof.nc
# Processing 20121123_prof.nc
# Processing 20121124_prof.nc
# Processing 20121125_prof.nc
# Processing 20121126_prof.nc
# Processing 20121127_prof.nc
# Processing 20121128_prof.nc
# Processing 20121129_prof.nc
# Processing 20121130_prof.nc
# Processing 20121201_prof.nc
# Processing 20121202_prof.nc
# Processing 20121203_prof.nc
# Processing 20121204_prof.nc
# Processing 20121205_prof.nc
# Processing 20121206_prof.nc
# Processing 20121207_prof.nc
# Processing 20121208_prof.nc
# Processing 20121209_prof.nc
# Processing 20121210_prof.nc
# Processing 20121211_prof.nc
# Processing 20121212_prof.nc
# Processing 20121213_prof.nc
# Processing 20121214_prof.nc
# Processing 20121215_prof.nc
# Processing 20121216_prof.nc
# Processing 20121217_prof.nc
# Processing 20121218_prof.nc
# Processing 20121219_prof.nc
# Processing 20121220_prof.nc
# Processing 20121221_prof.nc
# Processing 20121222_prof.nc
# Processing 20121223_prof.nc
# Processing 20121224_prof.nc
# Processing 20121225_prof.nc
# Processing 20121226_prof.nc
# Processing 20121227_prof.nc
# Processing 20121228_prof.nc
# Processing 20121229_prof.nc
# Processing 20121230_prof.nc
# Processing 20121231_prof.nc

# %% [markdown]
# ## Plot the locations of all profiles

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %%
    sourcefile=open(jsonfile,'rU',encoding='utf-8')
    infos=json.load(sourcefile)
    nb_profilesEN4=len(infos)
    list_profiles=infos.keys()

    all_lat=np.zeros((nb_profilesEN4))
    all_lon=np.zeros((nb_profilesEN4))
    
    for prof in np.arange(nb_profilesEN4):
        reference =  str(list(list_profiles)[prof])
        lat_prof = infos[reference]['latitude']
        lon_prof = infos[reference]['longitude']
        all_lat[prof]=lat_prof
        all_lon[prof]=lon_prof
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
len(all_lon)
# Out:
# 6514

# %%
def map_profiles_from_jsonfile(all_lat,all_lon):
    


    fig=plt.figure(figsize=(20,15))
    ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
#    ax.set_extent((lonmin, lonmax, latmin, latmax))
#    ax.coastlines(resolution="10m")
    gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                      alpha=0.5)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax.tick_params('both',labelsize=22)

    plt.scatter(all_lon, all_lat, c='g', linewidth='0', s=18);
    plt.title('EN4 profiles in GS region in 2010-2012', size=20);
    plt.savefig('profiles_GS_2010-2012.png')

# %%
map_profiles_from_jsonfile(all_lat,all_lon)
