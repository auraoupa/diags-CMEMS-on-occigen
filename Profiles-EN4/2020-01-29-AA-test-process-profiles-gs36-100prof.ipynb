# %% [markdown]
# # 0 - Load modules

# %%
import sys
import xarray as xr
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import glob
from netCDF4 import Dataset
import cartopy.crs as ccrs
import json
import os
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
config='GS36'
case='MPC001'
namezone='NATL60-CJM165_GS_y2012-2013'
jsonfile='/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/NATL60-CJM165_GS_y2012-2013_1.json'
dirn='/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/'+config+'-'+case+'/'

# %%
# !python 2020-01-29-AA-process-profiles-gs36.py --jsonfile '/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/NATL60-CJM165_GS_y2012-2013_1.json' --dir '/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/' --conf 'GS36' --case 'MPC001' --nz 'NATL60-CJM165_GS_y2012-2013'
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# 2020-01-29-AA-process-profiles-gs36.py:373: DeprecationWarning: 'U' mode is deprecated
#   sourcefile=open(jsonfile,'rU')
# 29/01/20 13:13
# Opening GS36
# 2020-01-29-AA-process-profiles-gs36.py:62: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   dsN = xr.open_mfdataset(tfiles,concat_dim='time_counter',decode_times=False, chunks={'deptht':1 ,'time_counter':10})
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 29/01/20 13:15
# dealing with profile A20121001-03173
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03173_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03175
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03175_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03182
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03182_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03196
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03196_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03200
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03200_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03206
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03206_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03208
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03208_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03213
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03213_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03215
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03215_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03227
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03227_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03234
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03234_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03236
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03236_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03247
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03247_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03253
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03253_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03261
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03261_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03266
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03266_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-03268
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-03268_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39744
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39744_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39745
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39745_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39746
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39746_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39747
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39747_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39748
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39748_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39756
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39756_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39757
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39757_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39758
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39758_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39759
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39759_GS36-MPC001_TS.nc already exists
# dealing with profile A20121001-39760
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39760_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39760'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39760_GS36-MPC001_TS.nc
# dealing with profile A20121001-39762
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39762_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39762'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39762_GS36-MPC001_TS.nc
# dealing with profile A20121001-39763
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39763_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39763'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39763_GS36-MPC001_TS.nc
# dealing with profile A20121001-39764
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39764_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39764'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39764_GS36-MPC001_TS.nc
# dealing with profile A20121001-39765
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39765_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39765'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39765_GS36-MPC001_TS.nc
# dealing with profile A20121001-39766
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39766_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39766'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39766_GS36-MPC001_TS.nc
# dealing with profile A20121001-39768
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39768_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39768'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39768_GS36-MPC001_TS.nc
# dealing with profile A20121001-39769
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39769_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39769'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39769_GS36-MPC001_TS.nc
# dealing with profile A20121001-39770
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39770_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39770'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39770_GS36-MPC001_TS.nc
# dealing with profile A20121001-39771
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39771_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39771'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39771_GS36-MPC001_TS.nc
# dealing with profile A20121001-39772
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39772_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39772'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39772_GS36-MPC001_TS.nc
# dealing with profile A20121001-39774
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39774_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39774'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39774_GS36-MPC001_TS.nc
# dealing with profile A20121001-39775
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39775_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39775'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39775_GS36-MPC001_TS.nc
# dealing with profile A20121001-39776
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39776_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39776'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39776_GS36-MPC001_TS.nc
# dealing with profile A20121001-39777
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39777_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39777'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39777_GS36-MPC001_TS.nc
# dealing with profile A20121001-39778
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39778_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39778'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39778_GS36-MPC001_TS.nc
# dealing with profile A20121001-39780
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39780_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39780'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39780_GS36-MPC001_TS.nc
# dealing with profile A20121001-39781
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39781_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39781'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39781_GS36-MPC001_TS.nc
# dealing with profile A20121001-39782
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39782_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39782'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39782_GS36-MPC001_TS.nc
# dealing with profile A20121001-39784
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39784_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39784'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39784_GS36-MPC001_TS.nc
# dealing with profile A20121001-39785
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39785_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39785'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39785_GS36-MPC001_TS.nc
# dealing with profile A20121001-39786
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39786_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39786'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39786_GS36-MPC001_TS.nc
# dealing with profile A20121001-39787
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39787_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39787'
# selected profile falls within GS36 boundaries, the program is proceeding
# output file is /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/profiles_EN4-A20121001-39787_GS36-MPC001_TS.nc
# dealing with profile A20121001-39788
# /scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001//profiles_EN4-A20121001-39788_GS36-MPC001_TS.nc does not exist; lets process
# Processing profile  b' A20121001-39788'
