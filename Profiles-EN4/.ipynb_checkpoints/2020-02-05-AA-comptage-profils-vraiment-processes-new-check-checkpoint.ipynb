# %%
## path for mdules
import sys
import warnings
warnings.filterwarnings('ignore')


## imports

import numpy as np
import dask
import xarray as xr
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import glob as glob
import matplotlib.gridspec as gridspec
import time
from dask.diagnostics import ProgressBar
from datetime import date
import yaml
import io
import json
import os

# %%
def process(jsonfile,infos,prof,dsN,latN,lonN,timN,config,case,namezone):
        ''' Make all the steps needed to create the final netcdf files for one profile
        '''
        list_profiles = infos.keys()
        reference =  str(list(list_profiles)[prof])
        print('Processing profile ', reference)
        lat_prof = infos[list(list_profiles)[prof]]['latitude']
        lon_prof = infos[list(list_profiles)[prof]]['longitude']
        date_prof = infos[list(list_profiles)[prof]]['date']
        file_prof = infos[list(list_profiles)[prof]]['file']
        prof_prof = infos[list(list_profiles)[prof]]['profile no']

        up=check_process_profile(file_prof,prof_prof,dsN,latN,lonN,timN)
        
        return up

# %%
def open_model(config,case):
        print('Opening data')
        tfiles="/store/colombo/"+config+"/"+config+"-"+case+"-S/1d/2012/"+config+"-"+case+"_y20??m??d??.1d_gridT.nc"

        ##Open NATL60 files to get boundaries of domain

        dsN = xr.open_mfdataset(tfiles,decode_times=False, chunks={'deptht':1 ,'time_counter':10})

        latN = dsN.nav_lat
        lonN = dsN.nav_lon
        timN = dsN.time_counter
        return dsN,latN,lonN,timN

# %%
def check_prof_boundaries(dsN,latN,lonN,timN,lat_prof,lon_prof,date_prof):
        ''' Check if the selected profile falls within model boundaries
        '''

        lamin=np.nanmin(latN.values)
        lamax=np.nanmax(latN.values)
        lomin=np.nanmin(lonN.values)
        lomax=np.nanmax(lonN.values)

        if (lamin < lat_prof < lamax) & (lomin < lon_prof < lomax) :
                check=0.
                print("selected profile falls within model boundaries, the program is proceeding")
        else:
                check=1.
                print("selected profile does not fall within model boundaries, the program is stopping")
        return check

# %%
def check_process_profile(fileEN4,ref_prof,dsN,latN,lonN,timN):
        #select NATL60 data at the closest depth and within 0.25 and 15days near the location and date of the ARGO profile
        diren4="/scratch/cnt0024/hmg2840/albert7a/EN4/"
        tfileEN4=diren4+fileEN4

        dsen4=xr.open_dataset(tfileEN4)

        laten4=dsen4['LATITUDE'][ref_prof]
        lonen4=dsen4['LONGITUDE'][ref_prof]
        depen4=dsen4['DEPH_CORRECTED'][ref_prof]
        refen4=dsen4['DC_REFERENCE'][ref_prof]
        dayen4=dsen4['JULD'][ref_prof]

        observation_lon=lonen4
        observation_lat=laten4
        
        #Coarse box in which EN4 profile is contained
        step=1
        indxBOX=np.where((lonN>observation_lon-1)&(lonN<observation_lon+1)&(latN>observation_lat-1)&(latN<observation_lat+1))
        if len(indxBOX[0]) < 1:
            print('profile is not really in the domain; exiting')
            return 0
        else:
            up={str(refen4):{'reference':str(refen4.values),'file':fileEN4,'latitude':float(laten4.values),'longitude':float(lonen4.values),'date':str(dayen4.values)}}
            return up

# %%
jsonfile = '/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_EU_y2012-2013/NATL60-CJM165_EU_y2012-2013_1.json'
dirn = '/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_EU_y2012-2013/EU36-MPC001/'
config = 'EU36'
case = 'MPC001'
namezone = 'NATL60-CJM165_EU_y2012-2013'

sourcefile=open(jsonfile,'rU')
infos=json.load(sourcefile)
nb_profilesEN4=len(infos)

print(time.strftime('%d/%m/%y %H:%M',time.localtime()))
dsN,latN,lonN,timN = open_model(config,case)
print(time.strftime('%d/%m/%y %H:%M',time.localtime()))

for prof in np.arange(nb_profilesEN4):

    list_profiles = infos.keys()
    reference = str(list(list_profiles)[prof])
    reference_profile=reference[-16:-1]
    print("dealing with profile "+reference_profile)

    up=process(jsonfile,infos,prof,dsN,latN,lonN,timN,config,case,namezone)

    if up == 0:
        print('pas de prof')
    else:
        if 'dictyml' in locals():
            dictyml.update(up)
        else:
            dictyml=up

newjson='/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_EU_y2012-2013/NATL60-CJM165_EU_y2012-2013_true_1.json'

 
with io.open(newjson, 'w', encoding='utf8') as outfile:
    outfile.write(str(json.dumps(dictyml, sort_keys=True,indent=4, separators=(',', ': '))))
# Out:
# 04/02/20 15:26
# Opening data
# 04/02/20 15:26
# dealing with profile A20121001-03180
# Processing profile  b' A20121001-03180'
# dealing with profile A20121001-03183
# Processing profile  b' A20121001-03183'
# dealing with profile A20121001-03275
# Processing profile  b' A20121001-03275'
# dealing with profile A20121001-03276
# Processing profile  b' A20121001-03276'
# dealing with profile A20121001-03280
# Processing profile  b' A20121001-03280'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-03285
# Processing profile  b' A20121001-03285'
# dealing with profile A20121001-39727
# Processing profile  b' A20121001-39727'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39729
# Processing profile  b' A20121001-39729'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39730
# Processing profile  b' A20121001-39730'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39731
# Processing profile  b' A20121001-39731'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39732
# Processing profile  b' A20121001-39732'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39733
# Processing profile  b' A20121001-39733'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39734
# Processing profile  b' A20121001-39734'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39735
# Processing profile  b' A20121001-39735'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39736
# Processing profile  b' A20121001-39736'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39901
# Processing profile  b' A20121001-39901'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39902
# Processing profile  b' A20121001-39902'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39903
# Processing profile  b' A20121001-39903'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39904
# Processing profile  b' A20121001-39904'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39905
# Processing profile  b' A20121001-39905'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39906
# Processing profile  b' A20121001-39906'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39907
# Processing profile  b' A20121001-39907'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39922
# Processing profile  b' A20121001-39922'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39923
# Processing profile  b' A20121001-39923'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39934
# Processing profile  b' A20121001-39934'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39935
# Processing profile  b' A20121001-39935'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39936
# Processing profile  b' A20121001-39936'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39937
# Processing profile  b' A20121001-39937'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39938
# Processing profile  b' A20121001-39938'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39939
# Processing profile  b' A20121001-39939'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39940
# Processing profile  b' A20121001-39940'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39941
# Processing profile  b' A20121001-39941'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39957
# Processing profile  b' A20121001-39957'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39958
# Processing profile  b' A20121001-39958'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39959
# Processing profile  b' A20121001-39959'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39960
# Processing profile  b' A20121001-39960'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39961
# Processing profile  b' A20121001-39961'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39962
# Processing profile  b' A20121001-39962'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39963
# Processing profile  b' A20121001-39963'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39964
# Processing profile  b' A20121001-39964'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39965
# Processing profile  b' A20121001-39965'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39966
# Processing profile  b' A20121001-39966'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39967
# Processing profile  b' A20121001-39967'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39968
# Processing profile  b' A20121001-39968'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39969
# Processing profile  b' A20121001-39969'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39970
# Processing profile  b' A20121001-39970'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121001-39994
# Processing profile  b' A20121001-39994'
# dealing with profile A20121001-42806
# Processing profile  b' A20121001-42806'
# dealing with profile A20121001-69083
# Processing profile  b' A20121001-69083'
# dealing with profile A20121001-69092
# Processing profile  b' A20121001-69092'
# dealing with profile A20121001-69104
# Processing profile  b' A20121001-69104'
# dealing with profile A20121001-69117
# Processing profile  b' A20121001-69117'
# dealing with profile A20121001-69124
# Processing profile  b' A20121001-69124'
# dealing with profile A20121001-69135
# Processing profile  b' A20121001-69135'
# dealing with profile A20121001-88803
# Processing profile  b' A20121001-88803'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-03316
# Processing profile  b' A20121002-03316'
# dealing with profile A20121002-03325
# Processing profile  b' A20121002-03325'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-03350
# Processing profile  b' A20121002-03350'
# dealing with profile A20121002-03356
# Processing profile  b' A20121002-03356'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-03375
# Processing profile  b' A20121002-03375'
# dealing with profile A20121002-03380
# Processing profile  b' A20121002-03380'
# dealing with profile A20121002-03401
# Processing profile  b' A20121002-03401'
# dealing with profile A20121002-03409
# Processing profile  b' A20121002-03409'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39896
# Processing profile  b' A20121002-39896'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39897
# Processing profile  b' A20121002-39897'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39898
# Processing profile  b' A20121002-39898'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39899
# Processing profile  b' A20121002-39899'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39908
# Processing profile  b' A20121002-39908'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39909
# Processing profile  b' A20121002-39909'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39910
# Processing profile  b' A20121002-39910'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39911
# Processing profile  b' A20121002-39911'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39912
# Processing profile  b' A20121002-39912'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39913
# Processing profile  b' A20121002-39913'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39914
# Processing profile  b' A20121002-39914'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39915
# Processing profile  b' A20121002-39915'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39916
# Processing profile  b' A20121002-39916'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39917
# Processing profile  b' A20121002-39917'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39918
# Processing profile  b' A20121002-39918'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39924
# Processing profile  b' A20121002-39924'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39925
# Processing profile  b' A20121002-39925'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39926
# Processing profile  b' A20121002-39926'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39927
# Processing profile  b' A20121002-39927'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39928
# Processing profile  b' A20121002-39928'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39929
# Processing profile  b' A20121002-39929'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39930
# Processing profile  b' A20121002-39930'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39931
# Processing profile  b' A20121002-39931'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39942
# Processing profile  b' A20121002-39942'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39943
# Processing profile  b' A20121002-39943'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39944
# Processing profile  b' A20121002-39944'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39945
# Processing profile  b' A20121002-39945'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39946
# Processing profile  b' A20121002-39946'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39947
# Processing profile  b' A20121002-39947'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39948
# Processing profile  b' A20121002-39948'
# profile is not really in the domain; exiting
# pas de prof
# dealing with profile A20121002-39949
# Processing profile  b' A20121002-39949'
