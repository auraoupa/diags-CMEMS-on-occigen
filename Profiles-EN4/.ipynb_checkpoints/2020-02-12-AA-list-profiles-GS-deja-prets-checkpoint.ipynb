# %%
file_list_EU36_MPC001=open("/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC001/list_vert_GS36-MPC001.txt","r")
list_EU36_MPC001=file_list_EU36_MPC001.read()
list_list_EU_MPC001=list_EU36_MPC001.split("\n")

# %%
file_list_EU36_MPC002=open("/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC002/list_vert_GS36-MPC002.txt","r")
list_EU36_MPC002=file_list_EU36_MPC002.read()
prof_EU_MPC002=list_EU36_MPC002.split("\n")

# %%
list_commune_MPC001_MPC002=[]
for prof in list_list_EU_MPC001:
    if prof in prof_EU_MPC002:
        list_commune_MPC001_MPC002.append(prof)

# %%
file_list_EU36_MPC003=open("/scratch/cnt0024/hmg2840/albert7a/EN4/profiles_files/NATL60-CJM165_GS_y2012-2013/GS36-MPC003/list_vert_GS36-MPC003.txt","r")
list_EU36_MPC003=file_list_EU36_MPC003.read()
prof_EU_MPC003=list_EU36_MPC003.split("\n")

# %%
list_commune_MPC001_MPC002_MPC003=[]
for prof in list_commune_MPC001_MPC002:
    if prof in prof_EU_MPC003:
        list_commune_MPC001_MPC002_MPC003.append(prof)

# %%
print(len(list_commune_MPC001_MPC002_MPC003))
# Out:
# 18174

# %%
list_prof_commune_MPC001_MPC002_MPC003=[]
for prof in list_commune_MPC001_MPC002_MPC003:
    list_prof_commune_MPC001_MPC002_MPC003.append(prof[4:])

# %%
print(str(list_prof_commune_MPC001_MPC002_MPC003[0]))
# Out:
# A20121001-03173

# %%
import numpy as np
import dask
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import glob as glob
import time
from datetime import date
import io
import json
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
latmin,latmax,lonmin,lonmax=(27,48,-81,-40)
datemin,datemax=('2012-10-01','2013-09-30')
jsonfile='NATL60-CJM165_GS_y2012-2013_final.json'

# %%
file='/scratch/cnt0024/hmg2840/albert7a/EN4/EN.4.2.0.f.profiles.g10.201201.nc'
ds=xr.open_dataset(file)

# %%
def select_profiles(latmin,latmax,lonmin,lonmax,datemin,datemax,jsonfile):
        ''' Identify all the EN4 profiles that fall within the selected zone and period
        '''
        ## Datasets

        #EN4
        diren4="/scratch/cnt0024/hmg2840/albert7a/EN4/"

        yearmin=datemin[0:4]
        monthmin=datemin[5:7]
        yearmax=datemax[0:4]
        monthmax=datemax[5:7]

        list_filesEN4=[]
        if yearmin == yearmax:
            for m in np.arange(int(monthmin),int(monthmax)+1):
                if m < 10:
                    list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+yearmin+'0'+str(m)+'.nc')
                else:
                    list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+yearmin+str(m)+'.nc')
        else:
            for m in np.arange(int(monthmin),13):
                if m < 10:
                    list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+yearmin+'0'+str(m)+'.nc')
                else:
                    list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+yearmin+str(m)+'.nc')
        if int(yearmin)+1 == int(yearmax):
            for m in np.arange(1,int(monthmax)+1):
                if m < 10:
                    list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+yearmax+'0'+str(m)+'.nc')
                else:
                    list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+yearmax+str(m)+'.nc')
        else:
            for year in np.arange(int(yearmin)+1,int(yearmax)):
                for m in np.arange(1,13):
                    if m < 10:
                        list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+str(year)+'0'+str(m)+'.nc')
                    else:
                        list_filesEN4.append('EN.4.2.0.f.profiles.g10.'+str(year)+str(m)+'.nc')
        print(list_filesEN4)

        datetmin=pd.to_datetime(datemin)
        datetmax=pd.to_datetime(datemax)
        ttmin=datetime.datetime(int(datetmin.strftime('%Y')),int(datetmin.strftime('%m')),int(datetmin.strftime('%d')),int(datetmin.strftime('%H')),int(datetmin.strftime('%M')))
        ttmax=datetime.datetime(int(datetmax.strftime('%Y')),int(datetmax.strftime('%m')),int(datetmax.strftime('%d')),int(datetmax.strftime('%H')),int(datetmax.strftime('%M')))
        tsecmin=(ttmin-datetime.datetime(1958,1,1,0,0)).total_seconds()
        tsecmax=(ttmax-datetime.datetime(1958,1,1,0,0)).total_seconds()

        for f in np.arange(len(list_filesEN4)):
            fileEN4=list_filesEN4[f]
            print('Processing '+str(fileEN4))
            tfileEN4=diren4+fileEN4
            dsen4=xr.open_dataset(tfileEN4)
            laten4=dsen4['LATITUDE']
            lonen4=dsen4['LONGITUDE']
            dayen4=dsen4['JULD']
            refen4=dsen4['DC_REFERENCE']
                      
            indz=np.where((lonmin<lonen4.values)&(lonen4.values<lonmax)&(latmin<laten4.values)&(laten4.values<latmax))
            prof_zone=[]
            tsecen4z=[]
            for ref in np.arange(len(indz[0])):
                dateen4= pd.to_datetime(str(dayen4[indz[0][ref]].values))
                ten4 = datetime.datetime(int(dateen4.strftime('%Y')),int(dateen4.strftime('%m')),int(dateen4.strftime('%d')),int(dateen4.strftime('%H')),int(dateen4.strftime('%M')))
                tsecen4=(ten4-datetime.datetime(1958,1,1,0,0)).total_seconds()
                if (tsecen4 < tsecmax) & (tsecen4 > tsecmin):
                    prof_zone.append(indz[0][ref])
                    tsecen4z.append(tsecen4)
                    

            for ref in np.arange(len(prof_zone)):
                ref_str=str(refen4[prof_zone[ref]].values)[-16:-1]
                if ref_str in list_prof_commune_MPC001_MPC002_MPC003:
                    print(ref_str+' est bien dans la liste')
                    if 'dictyml' in locals():
                        up={str(refen4[prof_zone[ref]].values):{'reference':str(refen4[prof_zone[ref]].values),'file':fileEN4,'profile no':int(prof_zone[ref]),'latitude':float(laten4[prof_zone[ref]].values),'longitude':float(lonen4[prof_zone[ref]].values),'date':str(dayen4[prof_zone[ref]].values)}}
                        dictyml.update(up)
                    else:
                        dictyml={str(refen4[prof_zone[ref]].values):{'reference':str(refen4[prof_zone[ref]].values),'file':fileEN4,'profile no':int(prof_zone[ref]),'latitude':float(laten4[prof_zone[ref]].values),'longitude':float(lonen4[prof_zone[ref]].values),'date':str(dayen4[prof_zone[ref]].values)}}
                    
        with io.open(jsonfile, 'w', encoding='utf8') as outfile:
            outfile.write(str(json.dumps(dictyml, sort_keys=True,indent=4, separators=(',', ': '))))

# %%
select_profiles(latmin,latmax,lonmin,lonmax,datemin,datemax,jsonfile)
# Out:
# ['EN.4.2.0.f.profiles.g10.201210.nc', 'EN.4.2.0.f.profiles.g10.201211.nc', 'EN.4.2.0.f.profiles.g10.201212.nc', 'EN.4.2.0.f.profiles.g10.201301.nc', 'EN.4.2.0.f.profiles.g10.201302.nc', 'EN.4.2.0.f.profiles.g10.201303.nc', 'EN.4.2.0.f.profiles.g10.201304.nc', 'EN.4.2.0.f.profiles.g10.201305.nc', 'EN.4.2.0.f.profiles.g10.201306.nc', 'EN.4.2.0.f.profiles.g10.201307.nc', 'EN.4.2.0.f.profiles.g10.201308.nc', 'EN.4.2.0.f.profiles.g10.201309.nc']
# Processing EN.4.2.0.f.profiles.g10.201210.nc
# A20121001-03173 est bien dans la liste
# A20121001-03175 est bien dans la liste
# A20121001-03182 est bien dans la liste
# A20121001-03196 est bien dans la liste
# A20121001-03200 est bien dans la liste
# A20121001-03206 est bien dans la liste
# A20121001-03208 est bien dans la liste
# A20121001-03213 est bien dans la liste
# A20121001-03215 est bien dans la liste
# A20121001-03227 est bien dans la liste
# A20121001-03234 est bien dans la liste
# A20121001-03236 est bien dans la liste
# A20121001-03247 est bien dans la liste
# A20121001-03253 est bien dans la liste
# A20121001-03261 est bien dans la liste
# A20121001-03266 est bien dans la liste
# A20121001-03268 est bien dans la liste
# A20121002-03288 est bien dans la liste
# A20121002-03309 est bien dans la liste
# A20121002-03315 est bien dans la liste
# A20121002-03323 est bien dans la liste
# A20121002-03324 est bien dans la liste
# A20121002-03334 est bien dans la liste
# A20121002-03336 est bien dans la liste
# A20121002-03348 est bien dans la liste
# A20121002-03349 est bien dans la liste
# A20121002-03361 est bien dans la liste
# A20121002-03367 est bien dans la liste
# A20121002-03370 est bien dans la liste
# A20121002-03371 est bien dans la liste
# A20121002-03376 est bien dans la liste
# A20121002-03389 est bien dans la liste
# A20121002-03400 est bien dans la liste
# A20121003-03418 est bien dans la liste
# A20121003-03424 est bien dans la liste
# A20121003-03426 est bien dans la liste
# A20121003-03429 est bien dans la liste
# A20121003-03434 est bien dans la liste
# A20121003-03444 est bien dans la liste
# A20121003-03453 est bien dans la liste
# A20121003-03455 est bien dans la liste
# A20121003-03458 est bien dans la liste
# A20121003-03463 est bien dans la liste
# A20121003-03472 est bien dans la liste
# A20121003-03481 est bien dans la liste
# A20121003-03485 est bien dans la liste
# A20121003-03494 est bien dans la liste
# A20121003-03495 est bien dans la liste
# A20121003-03519 est bien dans la liste
# A20121004-03525 est bien dans la liste
# A20121004-03548 est bien dans la liste
# A20121004-03552 est bien dans la liste
# A20121004-03556 est bien dans la liste
# A20121004-03568 est bien dans la liste
# A20121004-03583 est bien dans la liste
# A20121004-03592 est bien dans la liste
# A20121004-03600 est bien dans la liste
# A20121005-03651 est bien dans la liste
# A20121005-03652 est bien dans la liste
# A20121005-03655 est bien dans la liste
# A20121005-03669 est bien dans la liste
# A20121005-03678 est bien dans la liste
# A20121005-03679 est bien dans la liste
# A20121005-03685 est bien dans la liste
# A20121005-03688 est bien dans la liste
# A20121005-03694 est bien dans la liste
# A20121005-03703 est bien dans la liste
# A20121005-03711 est bien dans la liste
# A20121005-03715 est bien dans la liste
# A20121005-03725 est bien dans la liste
# A20121005-03734 est bien dans la liste
# A20121005-03740 est bien dans la liste
# A20121005-03742 est bien dans la liste
# A20121005-03744 est bien dans la liste
# A20121005-03757 est bien dans la liste
# A20121006-03765 est bien dans la liste
# A20121006-03767 est bien dans la liste
# A20121006-03773 est bien dans la liste
# A20121006-03777 est bien dans la liste
# A20121006-03789 est bien dans la liste
# A20121006-03790 est bien dans la liste
# A20121006-03800 est bien dans la liste
# A20121006-03801 est bien dans la liste
# A20121006-03811 est bien dans la liste
# A20121006-03816 est bien dans la liste
# A20121006-03817 est bien dans la liste
# A20121006-03827 est bien dans la liste
# A20121006-03847 est bien dans la liste
# A20121007-03871 est bien dans la liste
# A20121007-03880 est bien dans la liste
# A20121007-03891 est bien dans la liste
# A20121007-03896 est bien dans la liste
# A20121007-03900 est bien dans la liste
# A20121007-03918 est bien dans la liste
# A20121007-03922 est bien dans la liste
# A20121007-03932 est bien dans la liste
# A20121007-03936 est bien dans la liste
# A20121007-03942 est bien dans la liste
# A20121007-03945 est bien dans la liste
# A20121007-03955 est bien dans la liste
# A20121007-03965 est bien dans la liste
# A20121008-03989 est bien dans la liste
# A20121008-03990 est bien dans la liste
# A20121008-03992 est bien dans la liste
# A20121008-03993 est bien dans la liste
# A20121008-04000 est bien dans la liste
# A20121008-04004 est bien dans la liste
# A20121008-04013 est bien dans la liste
# A20121008-04039 est bien dans la liste
# A20121008-04043 est bien dans la liste
# A20121008-04046 est bien dans la liste
# A20121008-04050 est bien dans la liste
# A20121008-04053 est bien dans la liste
# A20121008-04071 est bien dans la liste
# A20121009-04113 est bien dans la liste
# A20121009-04124 est bien dans la liste
# A20121009-04126 est bien dans la liste
# A20121009-04130 est bien dans la liste
# A20121009-04140 est bien dans la liste
# A20121009-04147 est bien dans la liste
# A20121009-04162 est bien dans la liste
# A20121009-04172 est bien dans la liste
# A20121009-04174 est bien dans la liste
# A20121009-04182 est bien dans la liste
# A20121010-04193 est bien dans la liste
# A20121010-04198 est bien dans la liste
# A20121010-04199 est bien dans la liste
# A20121010-04223 est bien dans la liste
# A20121010-04224 est bien dans la liste
# A20121010-04236 est bien dans la liste
# A20121010-04255 est bien dans la liste
# A20121010-04257 est bien dans la liste
# A20121010-04267 est bien dans la liste
# A20121011-04293 est bien dans la liste
# A20121011-04295 est bien dans la liste
# A20121011-04298 est bien dans la liste
# A20121011-04304 est bien dans la liste
# A20121011-04331 est bien dans la liste
# A20121011-04338 est bien dans la liste
# A20121011-04339 est bien dans la liste
# A20121011-04355 est bien dans la liste
# A20121011-04356 est bien dans la liste
# A20121011-04361 est bien dans la liste
# A20121011-04372 est bien dans la liste
# A20121012-04388 est bien dans la liste
# A20121012-04411 est bien dans la liste
# A20121012-04420 est bien dans la liste
# A20121012-04441 est bien dans la liste
# A20121012-04443 est bien dans la liste
# A20121012-04444 est bien dans la liste
# A20121012-04445 est bien dans la liste
# A20121012-04449 est bien dans la liste
# A20121012-04455 est bien dans la liste
# A20121012-04476 est bien dans la liste
# A20121013-04495 est bien dans la liste
# A20121013-04496 est bien dans la liste
# A20121013-04505 est bien dans la liste
# A20121013-04508 est bien dans la liste
# A20121013-04522 est bien dans la liste
# A20121013-04523 est bien dans la liste
# A20121013-04532 est bien dans la liste
# A20121013-04533 est bien dans la liste
# A20121013-04540 est bien dans la liste
# A20121013-04560 est bien dans la liste
# A20121013-04564 est bien dans la liste
# A20121013-04566 est bien dans la liste
# A20121013-04567 est bien dans la liste
# A20121013-04571 est bien dans la liste
# A20121013-04573 est bien dans la liste
# A20121013-04579 est bien dans la liste
# A20121014-04592 est bien dans la liste
# A20121014-04616 est bien dans la liste
# A20121014-04623 est bien dans la liste
# A20121014-04633 est bien dans la liste
# A20121014-04634 est bien dans la liste
# A20121014-04636 est bien dans la liste
# A20121014-04637 est bien dans la liste
# A20121014-04666 est bien dans la liste
# A20121014-04687 est bien dans la liste
# A20121015-04703 est bien dans la liste
# A20121015-04704 est bien dans la liste
# A20121015-04705 est bien dans la liste
# A20121015-04712 est bien dans la liste
# A20121015-04713 est bien dans la liste
# A20121015-04726 est bien dans la liste
# A20121015-04739 est bien dans la liste
# A20121015-04763 est bien dans la liste
# A20121015-04776 est bien dans la liste
# A20121015-04780 est bien dans la liste
# A20121015-04781 est bien dans la liste
# A20121015-04798 est bien dans la liste
# A20121015-04802 est bien dans la liste
# A20121016-04812 est bien dans la liste
# A20121016-04813 est bien dans la liste
# A20121016-04814 est bien dans la liste
# A20121016-04836 est bien dans la liste
# A20121016-04840 est bien dans la liste
# A20121016-04862 est bien dans la liste
# A20121016-04865 est bien dans la liste
# A20121017-04932 est bien dans la liste
# A20121017-04936 est bien dans la liste
# A20121017-04940 est bien dans la liste
# A20121017-04950 est bien dans la liste
# A20121017-04955 est bien dans la liste
# A20121017-04960 est bien dans la liste
# A20121017-04977 est bien dans la liste
# A20121017-04981 est bien dans la liste
# A20121017-04984 est bien dans la liste
# A20121017-04986 est bien dans la liste
# A20121017-05002 est bien dans la liste
# A20121018-05006 est bien dans la liste
# A20121018-05008 est bien dans la liste
# A20121018-05010 est bien dans la liste
# A20121018-05011 est bien dans la liste
# A20121018-05023 est bien dans la liste
# A20121018-05032 est bien dans la liste
# A20121018-05033 est bien dans la liste
# A20121018-05037 est bien dans la liste
# A20121018-05050 est bien dans la liste
# A20121018-05053 est bien dans la liste
# A20121018-05056 est bien dans la liste
# A20121018-05063 est bien dans la liste
# A20121018-05065 est bien dans la liste
# A20121018-05082 est bien dans la liste
# A20121018-05096 est bien dans la liste
# A20121019-05105 est bien dans la liste
# A20121019-05148 est bien dans la liste
# A20121019-05156 est bien dans la liste
# A20121019-05160 est bien dans la liste
# A20121019-05162 est bien dans la liste
# A20121019-05169 est bien dans la liste
# A20121019-05186 est bien dans la liste
# A20121019-05197 est bien dans la liste
# A20121020-05210 est bien dans la liste
# A20121020-05212 est bien dans la liste
# A20121020-05214 est bien dans la liste
# A20121020-05242 est bien dans la liste
# A20121020-05256 est bien dans la liste
# A20121020-05260 est bien dans la liste
# A20121020-05272 est bien dans la liste
# A20121020-05293 est bien dans la liste
# A20121021-05312 est bien dans la liste
# A20121021-05318 est bien dans la liste
# A20121021-05334 est bien dans la liste
# A20121021-05349 est bien dans la liste
# A20121021-05358 est bien dans la liste
# A20121021-05361 est bien dans la liste
# A20121021-05363 est bien dans la liste
# A20121021-05369 est bien dans la liste
# A20121021-05372 est bien dans la liste
# A20121021-05384 est bien dans la liste
# A20121021-05387 est bien dans la liste
# A20121021-05393 est bien dans la liste
# A20121021-05394 est bien dans la liste
# A20121021-05402 est bien dans la liste
# A20121022-05411 est bien dans la liste
# A20121022-05439 est bien dans la liste
# A20121022-05440 est bien dans la liste
# A20121022-05444 est bien dans la liste
# A20121022-05445 est bien dans la liste
# A20121022-05462 est bien dans la liste
# A20121022-05463 est bien dans la liste
# A20121022-05473 est bien dans la liste
# A20121022-05475 est bien dans la liste
# A20121022-05483 est bien dans la liste
# A20121022-05484 est bien dans la liste
# A20121022-05485 est bien dans la liste
# A20121022-05497 est bien dans la liste
# A20121023-05530 est bien dans la liste
# A20121023-05531 est bien dans la liste
# A20121023-05537 est bien dans la liste
# A20121023-05543 est bien dans la liste
# A20121023-05559 est bien dans la liste
# A20121023-05567 est bien dans la liste
# A20121023-05571 est bien dans la liste
# A20121023-05575 est bien dans la liste
# A20121023-05585 est bien dans la liste
# A20121023-05589 est bien dans la liste
# A20121023-05600 est bien dans la liste
# A20121023-05605 est bien dans la liste
# A20121023-05612 est bien dans la liste
# A20121023-05629 est bien dans la liste
# A20121024-05637 est bien dans la liste
# A20121024-05684 est bien dans la liste
# A20121024-05687 est bien dans la liste
# A20121024-05696 est bien dans la liste
# A20121024-05701 est bien dans la liste
# A20121024-05713 est bien dans la liste
# A20121025-05743 est bien dans la liste
# A20121025-05747 est bien dans la liste
# A20121025-05760 est bien dans la liste
# A20121025-05771 est bien dans la liste
# A20121025-05787 est bien dans la liste
# A20121025-05792 est bien dans la liste
# A20121025-05808 est bien dans la liste
# A20121025-05817 est bien dans la liste
# A20121025-05823 est bien dans la liste
# A20121025-05826 est bien dans la liste
# A20121025-05827 est bien dans la liste
# A20121025-05828 est bien dans la liste
# A20121025-05834 est bien dans la liste
# A20121025-05839 est bien dans la liste
# A20121026-05842 est bien dans la liste
# A20121026-05844 est bien dans la liste
# A20121026-05856 est bien dans la liste
# A20121026-05865 est bien dans la liste
# A20121026-05886 est bien dans la liste
# A20121026-05887 est bien dans la liste
# A20121026-05898 est bien dans la liste
# A20121026-05912 est bien dans la liste
# A20121027-05940 est bien dans la liste
# A20121027-05947 est bien dans la liste
# A20121027-05963 est bien dans la liste
# A20121027-05984 est bien dans la liste
# A20121027-05986 est bien dans la liste
# A20121027-05998 est bien dans la liste
# A20121027-06005 est bien dans la liste
# A20121028-06046 est bien dans la liste
# A20121028-06047 est bien dans la liste
# A20121028-06048 est bien dans la liste
# A20121028-06060 est bien dans la liste
# A20121028-06061 est bien dans la liste
# A20121028-06069 est bien dans la liste
# A20121028-06093 est bien dans la liste
# A20121028-06096 est bien dans la liste
# A20121028-06099 est bien dans la liste
# A20121028-06101 est bien dans la liste
# A20121028-06103 est bien dans la liste
# A20121028-06108 est bien dans la liste
# A20121028-06132 est bien dans la liste
# A20121029-06179 est bien dans la liste
# A20121029-06192 est bien dans la liste
# A20121029-06194 est bien dans la liste
# A20121029-06204 est bien dans la liste
# A20121029-06209 est bien dans la liste
# A20121029-06210 est bien dans la liste
# A20121029-06223 est bien dans la liste
# A20121029-06226 est bien dans la liste
# A20121029-06237 est bien dans la liste
# A20121029-06244 est bien dans la liste
# A20121029-06246 est bien dans la liste
# A20121031-06390 est bien dans la liste
# A20121031-06396 est bien dans la liste
# A20121031-06402 est bien dans la liste
# A20121031-06416 est bien dans la liste
# A20121031-06430 est bien dans la liste
# A20121031-06431 est bien dans la liste
# A20121031-06468 est bien dans la liste
# A20121031-06469 est bien dans la liste
# A20121031-06479 est bien dans la liste
# A20121031-06482 est bien dans la liste
# A20121031-06497 est bien dans la liste
# A20121026-38208 est bien dans la liste
# A20121026-38209 est bien dans la liste
# A20121026-38210 est bien dans la liste
# A20121026-38211 est bien dans la liste
# A20121026-38212 est bien dans la liste
# A20121026-38213 est bien dans la liste
# A20121027-38214 est bien dans la liste
# A20121027-38215 est bien dans la liste
# A20121027-38216 est bien dans la liste
# A20121027-38217 est bien dans la liste
# A20121027-38218 est bien dans la liste
# A20121027-38219 est bien dans la liste
# A20121027-38220 est bien dans la liste
# A20121027-38221 est bien dans la liste
# A20121027-38222 est bien dans la liste
# A20121027-38223 est bien dans la liste
# A20121027-38224 est bien dans la liste
# A20121027-38225 est bien dans la liste
# A20121028-38226 est bien dans la liste
# A20121028-38227 est bien dans la liste
# A20121028-38228 est bien dans la liste
# A20121028-38229 est bien dans la liste
# A20121028-38230 est bien dans la liste
# A20121028-38231 est bien dans la liste
# A20121028-38232 est bien dans la liste
# A20121028-38233 est bien dans la liste
# A20121028-38234 est bien dans la liste
# A20121028-38235 est bien dans la liste
# A20121028-38236 est bien dans la liste
# A20121028-38237 est bien dans la liste
# A20121029-38238 est bien dans la liste
# A20121029-38239 est bien dans la liste
# A20121029-38240 est bien dans la liste
# A20121029-38241 est bien dans la liste
# A20121029-38242 est bien dans la liste
# A20121029-38243 est bien dans la liste
# A20121026-38244 est bien dans la liste
# A20121026-38245 est bien dans la liste
# A20121026-38246 est bien dans la liste
# A20121026-38247 est bien dans la liste
# A20121026-38248 est bien dans la liste
# A20121026-38249 est bien dans la liste
# A20121027-38250 est bien dans la liste
# A20121027-38251 est bien dans la liste
# A20121027-38252 est bien dans la liste
# A20121027-38253 est bien dans la liste
# A20121027-38254 est bien dans la liste
# A20121027-38255 est bien dans la liste
# A20121027-38256 est bien dans la liste
# A20121027-38257 est bien dans la liste
# A20121027-38258 est bien dans la liste
# A20121027-38259 est bien dans la liste
# A20121027-38260 est bien dans la liste
# A20121027-38261 est bien dans la liste
# A20121028-38262 est bien dans la liste
# A20121028-38263 est bien dans la liste
# A20121028-38264 est bien dans la liste
# A20121028-38265 est bien dans la liste
# A20121028-38266 est bien dans la liste
# A20121028-38267 est bien dans la liste
# A20121028-38268 est bien dans la liste
# A20121028-38269 est bien dans la liste
# A20121028-38270 est bien dans la liste
# A20121028-38271 est bien dans la liste
# A20121028-38272 est bien dans la liste
# A20121029-38273 est bien dans la liste
# A20121029-38274 est bien dans la liste
# A20121029-38275 est bien dans la liste
# A20121029-38276 est bien dans la liste
# A20121029-38277 est bien dans la liste
# A20121029-38278 est bien dans la liste
# A20121029-38279 est bien dans la liste
# A20121029-38965 est bien dans la liste
# A20121029-38966 est bien dans la liste
# A20121029-38967 est bien dans la liste
# A20121029-38968 est bien dans la liste
# A20121029-38969 est bien dans la liste
# A20121029-38970 est bien dans la liste
# A20121030-38973 est bien dans la liste
# A20121030-38974 est bien dans la liste
# A20121030-38975 est bien dans la liste
# A20121030-38976 est bien dans la liste
# A20121031-38977 est bien dans la liste
# A20121031-38978 est bien dans la liste
# A20121031-38979 est bien dans la liste
# A20121031-38980 est bien dans la liste
# A20121029-38981 est bien dans la liste
# A20121029-38982 est bien dans la liste
# A20121029-38983 est bien dans la liste
# A20121029-38984 est bien dans la liste
# A20121029-38985 est bien dans la liste
# A20121030-38986 est bien dans la liste
# A20121030-38987 est bien dans la liste
# A20121030-38988 est bien dans la liste
# A20121030-38989 est bien dans la liste
# A20121030-38990 est bien dans la liste
# A20121030-38991 est bien dans la liste
# A20121030-38992 est bien dans la liste
# A20121031-38993 est bien dans la liste
# A20121031-38994 est bien dans la liste
# A20121031-38995 est bien dans la liste
# A20121031-38996 est bien dans la liste
# A20121031-38997 est bien dans la liste
# A20121031-39540 est bien dans la liste
# A20121031-39541 est bien dans la liste
# A20121031-39542 est bien dans la liste
# A20121031-39543 est bien dans la liste
# A20121031-39544 est bien dans la liste
# A20121031-39545 est bien dans la liste
# A20121031-39546 est bien dans la liste
# A20121031-39547 est bien dans la liste
# A20121031-39548 est bien dans la liste
# A20121031-39549 est bien dans la liste
# A20121031-39550 est bien dans la liste
# A20121031-39551 est bien dans la liste
# A20121031-39718 est bien dans la liste
# A20121031-39719 est bien dans la liste
# A20121030-39720 est bien dans la liste
# A20121001-39744 est bien dans la liste
# A20121001-39745 est bien dans la liste
# A20121001-39746 est bien dans la liste
# A20121001-39747 est bien dans la liste
# A20121001-39748 est bien dans la liste
# A20121001-39756 est bien dans la liste
# A20121001-39757 est bien dans la liste
# A20121001-39758 est bien dans la liste
# A20121001-39759 est bien dans la liste
# A20121001-39760 est bien dans la liste
# A20121001-40026 est bien dans la liste
# A20121001-40027 est bien dans la liste
# A20121001-40028 est bien dans la liste
# A20121002-40031 est bien dans la liste
# A20121002-40032 est bien dans la liste
# A20121002-40033 est bien dans la liste
# A20121002-40034 est bien dans la liste
# A20121002-40035 est bien dans la liste
# A20121002-40036 est bien dans la liste
# A20121002-40037 est bien dans la liste
# A20121002-40038 est bien dans la liste
# A20121002-40039 est bien dans la liste
# A20121002-40040 est bien dans la liste
# A20121002-40041 est bien dans la liste
# A20121002-40042 est bien dans la liste
# A20121003-40043 est bien dans la liste
# A20121003-40044 est bien dans la liste
# A20121003-40045 est bien dans la liste
# A20121003-40046 est bien dans la liste
# A20121003-40047 est bien dans la liste
# A20121001-40071 est bien dans la liste
# A20121001-40072 est bien dans la liste
# A20121001-40073 est bien dans la liste
# A20121001-40074 est bien dans la liste
# A20121001-40075 est bien dans la liste
# A20121001-40076 est bien dans la liste
# A20121002-40077 est bien dans la liste
# A20121002-40078 est bien dans la liste
# A20121002-40079 est bien dans la liste
# A20121002-40080 est bien dans la liste
# A20121002-40081 est bien dans la liste
# A20121002-40082 est bien dans la liste
# A20121002-40083 est bien dans la liste
# A20121002-40084 est bien dans la liste
# A20121002-40085 est bien dans la liste
# A20121002-40086 est bien dans la liste
# A20121002-40087 est bien dans la liste
# A20121002-40088 est bien dans la liste
# A20121003-40089 est bien dans la liste
# A20121003-40090 est bien dans la liste
# A20121003-40091 est bien dans la liste
# A20121003-40092 est bien dans la liste
# A20121003-40093 est bien dans la liste
# A20121003-40094 est bien dans la liste
# A20121003-40736 est bien dans la liste
# A20121003-40737 est bien dans la liste
# A20121003-40738 est bien dans la liste
# A20121003-40739 est bien dans la liste
# A20121003-40740 est bien dans la liste
# A20121003-40741 est bien dans la liste
# A20121003-40742 est bien dans la liste
# A20121004-40743 est bien dans la liste
# A20121004-40744 est bien dans la liste
# A20121004-40745 est bien dans la liste
# A20121004-40746 est bien dans la liste
# A20121004-40747 est bien dans la liste
# A20121004-40748 est bien dans la liste
# A20121004-40749 est bien dans la liste
# A20121004-40750 est bien dans la liste
# A20121004-40751 est bien dans la liste
# A20121004-40752 est bien dans la liste
# A20121004-40753 est bien dans la liste
# A20121004-40754 est bien dans la liste
# A20121005-40755 est bien dans la liste
# A20121005-40756 est bien dans la liste
# A20121005-40757 est bien dans la liste
# A20121005-40758 est bien dans la liste
# A20121005-40759 est bien dans la liste
# A20121005-40760 est bien dans la liste
# A20121003-40783 est bien dans la liste
# A20121003-40784 est bien dans la liste
# A20121003-40785 est bien dans la liste
# A20121003-40786 est bien dans la liste
# A20121003-40787 est bien dans la liste
# A20121003-40788 est bien dans la liste
# A20121004-40789 est bien dans la liste
# A20121004-40790 est bien dans la liste
# A20121004-40791 est bien dans la liste
# A20121004-40792 est bien dans la liste
# A20121004-40793 est bien dans la liste
# A20121004-40794 est bien dans la liste
# A20121004-40795 est bien dans la liste
# A20121004-40797 est bien dans la liste
# A20121004-40798 est bien dans la liste
# A20121004-40799 est bien dans la liste
# A20121004-40800 est bien dans la liste
# A20121005-40801 est bien dans la liste
# A20121005-40802 est bien dans la liste
# A20121005-40803 est bien dans la liste
# A20121005-40804 est bien dans la liste
# A20121005-40805 est bien dans la liste
# A20121005-40806 est bien dans la liste
# A20121005-41556 est bien dans la liste
# A20121005-41557 est bien dans la liste
# A20121005-41558 est bien dans la liste
# A20121005-41559 est bien dans la liste
# A20121005-41560 est bien dans la liste
# A20121005-41561 est bien dans la liste
# A20121006-41562 est bien dans la liste
# A20121006-41563 est bien dans la liste
# A20121006-41564 est bien dans la liste
# A20121006-41565 est bien dans la liste
# A20121006-41566 est bien dans la liste
# A20121006-41567 est bien dans la liste
# A20121006-41568 est bien dans la liste
# A20121006-41569 est bien dans la liste
# A20121006-41570 est bien dans la liste
# A20121006-41571 est bien dans la liste
# A20121006-41572 est bien dans la liste
# A20121006-41573 est bien dans la liste
# A20121007-41574 est bien dans la liste
# A20121007-41575 est bien dans la liste
# A20121007-41576 est bien dans la liste
# A20121007-41577 est bien dans la liste
# A20121007-41578 est bien dans la liste
# A20121007-41579 est bien dans la liste
# A20121007-41580 est bien dans la liste
# A20121007-41582 est bien dans la liste
# A20121007-41583 est bien dans la liste
# A20121007-41584 est bien dans la liste
# A20121007-41585 est bien dans la liste
# A20121008-41586 est bien dans la liste
# A20121008-41587 est bien dans la liste
# A20121008-41588 est bien dans la liste
# A20121008-41590 est bien dans la liste
# A20121008-41591 est bien dans la liste
# A20121008-41592 est bien dans la liste
# A20121008-41593 est bien dans la liste
# A20121008-41594 est bien dans la liste
# A20121008-41595 est bien dans la liste
# A20121008-41596 est bien dans la liste
# A20121009-41597 est bien dans la liste
# A20121009-41598 est bien dans la liste
# A20121009-41599 est bien dans la liste
# A20121009-41600 est bien dans la liste
# A20121009-41602 est bien dans la liste
# A20121009-41603 est bien dans la liste
# A20121005-41641 est bien dans la liste
# A20121005-41642 est bien dans la liste
# A20121005-41643 est bien dans la liste
# A20121005-41644 est bien dans la liste
# A20121005-41645 est bien dans la liste
# A20121005-41646 est bien dans la liste
# A20121006-41647 est bien dans la liste
# A20121006-41648 est bien dans la liste
# A20121006-41649 est bien dans la liste
# A20121006-41650 est bien dans la liste
# A20121006-41651 est bien dans la liste
# A20121006-41652 est bien dans la liste
# A20121006-41653 est bien dans la liste
# A20121006-41654 est bien dans la liste
# A20121006-41655 est bien dans la liste
# A20121006-41656 est bien dans la liste
# A20121006-41657 est bien dans la liste
# A20121006-41658 est bien dans la liste
# A20121007-41659 est bien dans la liste
# A20121007-41660 est bien dans la liste
# A20121007-41661 est bien dans la liste
# A20121007-41662 est bien dans la liste
# A20121007-41663 est bien dans la liste
# A20121007-41664 est bien dans la liste
# A20121007-41665 est bien dans la liste
# A20121007-41666 est bien dans la liste
# A20121007-41667 est bien dans la liste
# A20121007-41668 est bien dans la liste
# A20121007-41669 est bien dans la liste
# A20121007-41670 est bien dans la liste
# A20121008-41671 est bien dans la liste
# A20121008-41672 est bien dans la liste
# A20121008-41673 est bien dans la liste
# A20121008-41674 est bien dans la liste
# A20121008-41675 est bien dans la liste
# A20121008-41676 est bien dans la liste
# A20121008-41677 est bien dans la liste
# A20121008-41678 est bien dans la liste
# A20121008-41679 est bien dans la liste
# A20121008-41680 est bien dans la liste
# A20121008-41681 est bien dans la liste
# A20121008-41682 est bien dans la liste
# A20121009-41683 est bien dans la liste
# A20121009-41684 est bien dans la liste
# A20121009-41685 est bien dans la liste
# A20121009-41686 est bien dans la liste
# A20121009-41687 est bien dans la liste
# A20121009-41688 est bien dans la liste
# A20121009-42527 est bien dans la liste
# A20121009-42528 est bien dans la liste
# A20121009-42529 est bien dans la liste
# A20121009-42530 est bien dans la liste
# A20121009-42531 est bien dans la liste
# A20121010-42532 est bien dans la liste
# A20121010-42533 est bien dans la liste
# A20121010-42534 est bien dans la liste
# A20121010-42535 est bien dans la liste
# A20121010-42536 est bien dans la liste
# A20121009-42537 est bien dans la liste
# A20121009-42538 est bien dans la liste
# A20121009-42539 est bien dans la liste
# A20121009-42540 est bien dans la liste
# A20121009-42541 est bien dans la liste
# A20121009-42542 est bien dans la liste
# A20121010-42543 est bien dans la liste
# A20121010-42544 est bien dans la liste
# A20121010-42545 est bien dans la liste
# A20121010-42546 est bien dans la liste
# A20121010-42547 est bien dans la liste
# A20121010-42983 est bien dans la liste
# A20121010-42984 est bien dans la liste
# A20121010-42985 est bien dans la liste
# A20121010-42986 est bien dans la liste
# A20121010-42987 est bien dans la liste
# A20121010-42988 est bien dans la liste
# A20121010-42989 est bien dans la liste
# A20121011-42990 est bien dans la liste
# A20121011-42991 est bien dans la liste
# A20121011-42992 est bien dans la liste
# A20121011-42993 est bien dans la liste
# A20121011-42994 est bien dans la liste
# A20121011-42995 est bien dans la liste
# A20121011-42996 est bien dans la liste
# A20121011-42997 est bien dans la liste
# A20121011-42998 est bien dans la liste
# A20121011-42999 est bien dans la liste
# A20121012-43002 est bien dans la liste
# A20121012-43003 est bien dans la liste
# A20121012-43004 est bien dans la liste
# A20121012-43005 est bien dans la liste
# A20121012-43006 est bien dans la liste
# A20121010-43007 est bien dans la liste
# A20121010-43008 est bien dans la liste
# A20121010-43009 est bien dans la liste
# A20121010-43010 est bien dans la liste
# A20121010-43011 est bien dans la liste
# A20121010-43012 est bien dans la liste
# A20121010-43013 est bien dans la liste
# A20121011-43014 est bien dans la liste
# A20121011-43015 est bien dans la liste
# A20121011-43016 est bien dans la liste
# A20121011-43017 est bien dans la liste
# A20121011-43018 est bien dans la liste
# A20121011-43019 est bien dans la liste
# A20121011-43020 est bien dans la liste
# A20121011-43021 est bien dans la liste
# A20121011-43022 est bien dans la liste
# A20121011-43023 est bien dans la liste
# A20121011-43024 est bien dans la liste
# A20121012-43025 est bien dans la liste
# A20121012-43026 est bien dans la liste
# A20121012-43027 est bien dans la liste
# A20121012-43028 est bien dans la liste
# A20121012-43029 est bien dans la liste
# A20121012-43708 est bien dans la liste
# A20121012-43709 est bien dans la liste
# A20121012-43710 est bien dans la liste
# A20121012-43711 est bien dans la liste
# A20121012-43712 est bien dans la liste
# A20121012-43713 est bien dans la liste
# A20121012-43714 est bien dans la liste
# A20121013-43715 est bien dans la liste
# A20121013-43716 est bien dans la liste
# A20121013-43717 est bien dans la liste
# A20121013-43718 est bien dans la liste
# A20121013-43719 est bien dans la liste
# A20121013-43720 est bien dans la liste
# A20121013-43721 est bien dans la liste
# A20121013-43722 est bien dans la liste
# A20121013-43723 est bien dans la liste
# A20121013-43724 est bien dans la liste
# A20121014-43725 est bien dans la liste
# A20121014-43726 est bien dans la liste
# A20121014-43727 est bien dans la liste
# A20121014-43728 est bien dans la liste
# A20121014-43729 est bien dans la liste
# A20121014-43730 est bien dans la liste
# A20121014-43731 est bien dans la liste
# A20121014-43732 est bien dans la liste
# A20121014-43733 est bien dans la liste
# A20121014-43734 est bien dans la liste
# A20121014-43735 est bien dans la liste
# A20121015-43737 est bien dans la liste
# A20121015-43738 est bien dans la liste
# A20121015-43741 est bien dans la liste
# A20121015-43742 est bien dans la liste
# A20121012-43743 est bien dans la liste
# A20121012-43744 est bien dans la liste
# A20121012-43745 est bien dans la liste
# A20121012-43746 est bien dans la liste
# A20121012-43747 est bien dans la liste
# A20121012-43748 est bien dans la liste
# A20121012-43749 est bien dans la liste
# A20121013-43750 est bien dans la liste
# A20121013-43751 est bien dans la liste
# A20121013-43752 est bien dans la liste
# A20121013-43753 est bien dans la liste
# A20121013-43754 est bien dans la liste
# A20121013-43755 est bien dans la liste
# A20121013-43756 est bien dans la liste
# A20121013-43757 est bien dans la liste
# A20121013-43758 est bien dans la liste
# A20121013-43759 est bien dans la liste
# A20121013-43760 est bien dans la liste
# A20121014-43761 est bien dans la liste
# A20121014-43762 est bien dans la liste
# A20121014-43763 est bien dans la liste
# A20121014-43764 est bien dans la liste
# A20121014-43765 est bien dans la liste
# A20121014-43766 est bien dans la liste
# A20121014-43767 est bien dans la liste
# A20121014-43768 est bien dans la liste
# A20121014-43769 est bien dans la liste
# A20121014-43770 est bien dans la liste
# A20121014-43771 est bien dans la liste
# A20121014-43772 est bien dans la liste
# A20121015-43773 est bien dans la liste
# A20121015-43774 est bien dans la liste
# A20121015-43775 est bien dans la liste
# A20121015-43776 est bien dans la liste
# A20121015-43777 est bien dans la liste
# A20121015-43778 est bien dans la liste
# A20121015-44495 est bien dans la liste
# A20121015-44496 est bien dans la liste
# A20121015-44497 est bien dans la liste
# A20121015-44498 est bien dans la liste
# A20121015-44499 est bien dans la liste
# A20121016-44500 est bien dans la liste
# A20121016-44501 est bien dans la liste
# A20121016-44502 est bien dans la liste
# A20121016-44503 est bien dans la liste
# A20121016-44504 est bien dans la liste
# A20121016-44505 est bien dans la liste
# A20121016-44507 est bien dans la liste
# A20121016-44508 est bien dans la liste
# A20121016-44510 est bien dans la liste
# A20121016-44511 est bien dans la liste
# A20121017-44512 est bien dans la liste
# A20121017-44513 est bien dans la liste
# A20121017-44514 est bien dans la liste
# A20121017-44515 est bien dans la liste
# A20121017-44517 est bien dans la liste
# A20121015-44518 est bien dans la liste
# A20121015-44519 est bien dans la liste
# A20121015-44520 est bien dans la liste
# A20121015-44521 est bien dans la liste
# A20121015-44522 est bien dans la liste
# A20121015-44523 est bien dans la liste
# A20121016-44524 est bien dans la liste
# A20121016-44525 est bien dans la liste
# A20121016-44526 est bien dans la liste
# A20121016-44527 est bien dans la liste
# A20121016-44528 est bien dans la liste
# A20121016-44529 est bien dans la liste
# A20121016-44530 est bien dans la liste
# A20121016-44531 est bien dans la liste
# A20121016-44532 est bien dans la liste
# A20121016-44533 est bien dans la liste
# A20121016-44534 est bien dans la liste
# A20121016-44535 est bien dans la liste
# A20121017-44536 est bien dans la liste
# A20121017-44537 est bien dans la liste
# A20121017-44538 est bien dans la liste
# A20121017-44539 est bien dans la liste
# A20121017-44540 est bien dans la liste
# A20121017-44541 est bien dans la liste
# A20121017-45196 est bien dans la liste
# A20121017-45197 est bien dans la liste
# A20121017-45198 est bien dans la liste
# A20121017-45199 est bien dans la liste
# A20121017-45200 est bien dans la liste
# A20121017-45201 est bien dans la liste
# A20121018-45202 est bien dans la liste
# A20121018-45203 est bien dans la liste
# A20121018-45204 est bien dans la liste
# A20121018-45205 est bien dans la liste
# A20121018-45206 est bien dans la liste
# A20121018-45207 est bien dans la liste
# A20121018-45208 est bien dans la liste
# A20121018-45209 est bien dans la liste
# A20121018-45210 est bien dans la liste
# A20121018-45211 est bien dans la liste
# A20121018-45212 est bien dans la liste
# A20121018-45213 est bien dans la liste
# A20121019-45214 est bien dans la liste
# A20121019-45215 est bien dans la liste
# A20121019-45216 est bien dans la liste
# A20121019-45217 est bien dans la liste
# A20121019-45218 est bien dans la liste
# A20121019-45219 est bien dans la liste
# A20121017-45220 est bien dans la liste
# A20121017-45221 est bien dans la liste
# A20121017-45222 est bien dans la liste
# A20121017-45223 est bien dans la liste
# A20121017-45224 est bien dans la liste
# A20121017-45225 est bien dans la liste
# A20121018-45226 est bien dans la liste
# A20121018-45227 est bien dans la liste
# A20121018-45228 est bien dans la liste
# A20121018-45229 est bien dans la liste
# A20121018-45230 est bien dans la liste
# A20121018-45231 est bien dans la liste
# A20121018-45232 est bien dans la liste
# A20121018-45233 est bien dans la liste
# A20121018-45234 est bien dans la liste
# A20121018-45235 est bien dans la liste
# A20121018-45236 est bien dans la liste
# A20121018-45237 est bien dans la liste
# A20121019-45238 est bien dans la liste
# A20121019-45239 est bien dans la liste
# A20121019-45240 est bien dans la liste
# A20121019-45241 est bien dans la liste
# A20121019-45242 est bien dans la liste
# A20121019-45243 est bien dans la liste
# A20121019-45906 est bien dans la liste
# A20121019-45907 est bien dans la liste
# A20121019-45908 est bien dans la liste
# A20121019-45909 est bien dans la liste
# A20121019-45910 est bien dans la liste
# A20121019-45911 est bien dans la liste
# A20121020-45912 est bien dans la liste
# A20121020-45913 est bien dans la liste
# A20121020-45914 est bien dans la liste
# A20121020-45916 est bien dans la liste
# A20121020-45918 est bien dans la liste
# A20121020-45919 est bien dans la liste
# A20121020-45920 est bien dans la liste
# A20121020-45921 est bien dans la liste
# A20121020-45922 est bien dans la liste
# A20121020-45923 est bien dans la liste
# A20121021-45924 est bien dans la liste
# A20121021-45925 est bien dans la liste
# A20121021-45927 est bien dans la liste
# A20121021-45928 est bien dans la liste
# A20121021-45929 est bien dans la liste
# A20121021-45930 est bien dans la liste
# A20121021-45931 est bien dans la liste
# A20121021-45932 est bien dans la liste
# A20121021-45933 est bien dans la liste
# A20121021-45934 est bien dans la liste
# A20121021-45935 est bien dans la liste
# A20121022-45936 est bien dans la liste
# A20121022-45937 est bien dans la liste
# A20121022-45939 est bien dans la liste
# A20121022-45940 est bien dans la liste
# A20121022-45941 est bien dans la liste
# A20121019-45942 est bien dans la liste
# A20121019-45943 est bien dans la liste
# A20121019-45944 est bien dans la liste
# A20121019-45945 est bien dans la liste
# A20121019-45946 est bien dans la liste
# A20121019-45947 est bien dans la liste
# A20121020-45948 est bien dans la liste
# A20121020-45949 est bien dans la liste
# A20121020-45950 est bien dans la liste
# A20121020-45951 est bien dans la liste
# A20121020-45952 est bien dans la liste
# A20121020-45953 est bien dans la liste
# A20121020-45954 est bien dans la liste
# A20121020-45955 est bien dans la liste
# A20121020-45956 est bien dans la liste
# A20121020-45957 est bien dans la liste
# A20121020-45958 est bien dans la liste
# A20121020-45959 est bien dans la liste
# A20121021-45960 est bien dans la liste
# A20121021-45961 est bien dans la liste
# A20121021-45962 est bien dans la liste
# A20121021-45963 est bien dans la liste
# A20121021-45964 est bien dans la liste
# A20121021-45965 est bien dans la liste
# A20121021-45966 est bien dans la liste
# A20121021-45967 est bien dans la liste
# A20121021-45968 est bien dans la liste
# A20121021-45969 est bien dans la liste
# A20121021-45970 est bien dans la liste
# A20121022-45971 est bien dans la liste
# A20121022-45972 est bien dans la liste
# A20121022-45973 est bien dans la liste
# A20121022-45974 est bien dans la liste
# A20121022-45975 est bien dans la liste
# A20121022-45976 est bien dans la liste
# A20121022-46620 est bien dans la liste
# A20121022-46621 est bien dans la liste
# A20121022-46622 est bien dans la liste
# A20121022-46623 est bien dans la liste
# A20121022-46624 est bien dans la liste
# A20121022-46625 est bien dans la liste
# A20121023-46626 est bien dans la liste
# A20121023-46627 est bien dans la liste
# A20121023-46628 est bien dans la liste
# A20121023-46629 est bien dans la liste
# A20121023-46630 est bien dans la liste
# A20121023-46631 est bien dans la liste
# A20121023-46632 est bien dans la liste
# A20121023-46633 est bien dans la liste
# A20121023-46634 est bien dans la liste
# A20121023-46635 est bien dans la liste
# A20121023-46636 est bien dans la liste
# A20121023-46637 est bien dans la liste
# A20121024-46638 est bien dans la liste
# A20121024-46639 est bien dans la liste
# A20121024-46640 est bien dans la liste
# A20121024-46641 est bien dans la liste
# A20121024-46642 est bien dans la liste
# A20121022-46644 est bien dans la liste
# A20121022-46645 est bien dans la liste
# A20121022-46646 est bien dans la liste
# A20121022-46647 est bien dans la liste
# A20121022-46648 est bien dans la liste
# A20121023-46649 est bien dans la liste
# A20121023-46650 est bien dans la liste
# A20121023-46651 est bien dans la liste
# A20121023-46652 est bien dans la liste
# A20121023-46653 est bien dans la liste
# A20121023-46654 est bien dans la liste
# A20121023-46655 est bien dans la liste
# A20121023-46656 est bien dans la liste
# A20121023-46657 est bien dans la liste
# A20121023-46658 est bien dans la liste
# A20121024-46659 est bien dans la liste
# A20121024-46660 est bien dans la liste
# A20121024-46661 est bien dans la liste
# A20121024-46662 est bien dans la liste
# A20121024-46663 est bien dans la liste
# A20121024-46664 est bien dans la liste
# A20121024-47169 est bien dans la liste
# A20121024-47170 est bien dans la liste
# A20121024-47171 est bien dans la liste
# A20121024-47172 est bien dans la liste
# A20121024-47173 est bien dans la liste
# A20121024-47174 est bien dans la liste
# A20121025-47175 est bien dans la liste
# A20121025-47176 est bien dans la liste
# A20121025-47177 est bien dans la liste
# A20121025-47178 est bien dans la liste
# A20121025-47179 est bien dans la liste
# A20121025-47180 est bien dans la liste
# A20121025-47181 est bien dans la liste
# A20121025-47182 est bien dans la liste
# A20121025-47183 est bien dans la liste
# A20121025-47184 est bien dans la liste
# A20121025-47185 est bien dans la liste
# A20121025-47186 est bien dans la liste
# A20121026-47187 est bien dans la liste
# A20121026-47188 est bien dans la liste
# A20121026-47189 est bien dans la liste
# A20121026-47190 est bien dans la liste
# A20121026-47191 est bien dans la liste
# A20121024-47192 est bien dans la liste
# A20121024-47193 est bien dans la liste
# A20121024-47194 est bien dans la liste
# A20121024-47195 est bien dans la liste
# A20121024-47196 est bien dans la liste
# A20121024-47197 est bien dans la liste
# A20121025-47198 est bien dans la liste
# A20121025-47199 est bien dans la liste
# A20121025-47200 est bien dans la liste
# A20121025-47201 est bien dans la liste
# A20121025-47202 est bien dans la liste
# A20121025-47203 est bien dans la liste
# A20121025-47204 est bien dans la liste
# A20121025-47205 est bien dans la liste
# A20121025-47206 est bien dans la liste
# A20121025-47207 est bien dans la liste
# A20121025-47208 est bien dans la liste
# A20121025-47209 est bien dans la liste
# A20121026-47210 est bien dans la liste
# A20121026-47211 est bien dans la liste
# A20121026-47212 est bien dans la liste
# A20121026-47213 est bien dans la liste
# A20121026-47214 est bien dans la liste
# A20121001-69082 est bien dans la liste
# A20121001-69086 est bien dans la liste
# A20121001-69090 est bien dans la liste
# A20121001-69091 est bien dans la liste
# A20121001-69098 est bien dans la liste
# A20121001-69099 est bien dans la liste
# A20121001-69102 est bien dans la liste
# A20121001-69103 est bien dans la liste
# A20121001-69109 est bien dans la liste
# A20121001-69112 est bien dans la liste
# A20121001-69113 est bien dans la liste
# A20121001-69114 est bien dans la liste
# A20121001-69119 est bien dans la liste
# A20121001-69120 est bien dans la liste
# A20121001-69122 est bien dans la liste
# A20121001-69123 est bien dans la liste
# A20121001-69125 est bien dans la liste
# A20121001-69128 est bien dans la liste
# A20121001-69129 est bien dans la liste
# A20121001-69133 est bien dans la liste
# A20121001-69134 est bien dans la liste
# A20121001-69136 est bien dans la liste
# A20121001-69138 est bien dans la liste
# A20121001-69142 est bien dans la liste
# A20121001-69148 est bien dans la liste
# A20121001-69149 est bien dans la liste
# A20121002-69168 est bien dans la liste
# A20121002-69176 est bien dans la liste
# A20121002-69205 est bien dans la liste
# A20121002-69209 est bien dans la liste
# A20121002-69217 est bien dans la liste
# A20121002-69221 est bien dans la liste
# A20121002-69222 est bien dans la liste
# A20121002-69223 est bien dans la liste
# A20121002-69231 est bien dans la liste
# A20121002-69235 est bien dans la liste
# A20121002-69236 est bien dans la liste
# A20121002-69237 est bien dans la liste
# A20121002-69241 est bien dans la liste
# A20121002-69242 est bien dans la liste
# A20121002-69250 est bien dans la liste
# A20121002-69259 est bien dans la liste
# A20121002-69266 est bien dans la liste
# A20121002-69267 est bien dans la liste
# A20121003-69280 est bien dans la liste
# A20121003-69287 est bien dans la liste
# A20121003-69288 est bien dans la liste
# A20121003-69302 est bien dans la liste
# A20121003-69314 est bien dans la liste
# A20121003-69320 est bien dans la liste
# A20121003-69328 est bien dans la liste
# A20121003-69331 est bien dans la liste
# A20121003-69338 est bien dans la liste
# A20121003-69342 est bien dans la liste
# A20121003-69347 est bien dans la liste
# A20121003-69351 est bien dans la liste
# A20121003-69352 est bien dans la liste
# A20121004-69392 est bien dans la liste
# A20121004-69394 est bien dans la liste
# A20121004-69395 est bien dans la liste
# A20121004-69398 est bien dans la liste
# A20121004-69399 est bien dans la liste
# A20121004-69402 est bien dans la liste
# A20121004-69404 est bien dans la liste
# A20121004-69408 est bien dans la liste
# A20121004-69410 est bien dans la liste
# A20121004-69417 est bien dans la liste
# A20121005-69446 est bien dans la liste
# A20121005-69450 est bien dans la liste
# A20121005-69453 est bien dans la liste
# A20121005-69454 est bien dans la liste
# A20121005-69456 est bien dans la liste
# A20121005-69461 est bien dans la liste
# A20121005-69463 est bien dans la liste
# A20121005-69465 est bien dans la liste
# A20121005-69466 est bien dans la liste
# A20121005-69468 est bien dans la liste
# A20121005-69469 est bien dans la liste
# A20121005-69471 est bien dans la liste
# A20121005-69472 est bien dans la liste
# A20121005-69473 est bien dans la liste
# A20121005-69477 est bien dans la liste
# A20121005-69478 est bien dans la liste
# A20121005-69484 est bien dans la liste
# A20121006-69490 est bien dans la liste
# A20121006-69493 est bien dans la liste
# A20121006-69496 est bien dans la liste
# A20121006-69498 est bien dans la liste
# A20121006-69501 est bien dans la liste
# A20121006-69502 est bien dans la liste
# A20121006-69504 est bien dans la liste
# A20121006-69505 est bien dans la liste
# A20121006-69506 est bien dans la liste
# A20121006-69508 est bien dans la liste
# A20121006-69513 est bien dans la liste
# A20121006-69516 est bien dans la liste
# A20121006-69518 est bien dans la liste
# A20121006-69522 est bien dans la liste
# A20121006-69523 est bien dans la liste
# A20121007-69546 est bien dans la liste
# A20121007-69547 est bien dans la liste
# A20121007-69548 est bien dans la liste
# A20121007-69552 est bien dans la liste
# A20121007-69556 est bien dans la liste
# A20121007-69559 est bien dans la liste
# A20121007-69561 est bien dans la liste
# A20121007-69564 est bien dans la liste
# A20121007-69566 est bien dans la liste
# A20121007-69567 est bien dans la liste
# A20121007-69568 est bien dans la liste
# A20121007-69572 est bien dans la liste
# A20121007-69574 est bien dans la liste
# A20121007-69576 est bien dans la liste
# A20121007-69580 est bien dans la liste
# A20121007-69584 est bien dans la liste
# A20121007-69587 est bien dans la liste
# A20121007-69590 est bien dans la liste
# A20121007-69591 est bien dans la liste
# A20121007-69593 est bien dans la liste
# A20121007-69599 est bien dans la liste
# A20121007-69600 est bien dans la liste
# A20121008-69604 est bien dans la liste
# A20121008-69608 est bien dans la liste
# A20121008-69609 est bien dans la liste
# A20121008-69612 est bien dans la liste
# A20121008-69614 est bien dans la liste
# A20121008-69616 est bien dans la liste
# A20121008-69619 est bien dans la liste
# A20121008-69622 est bien dans la liste
# A20121008-69624 est bien dans la liste
# A20121008-69630 est bien dans la liste
# A20121008-69631 est bien dans la liste
# A20121008-69634 est bien dans la liste
# A20121008-69640 est bien dans la liste
# A20121008-69643 est bien dans la liste
# A20121008-69645 est bien dans la liste
# A20121008-69647 est bien dans la liste
# A20121008-69648 est bien dans la liste
# A20121008-69649 est bien dans la liste
# A20121008-69651 est bien dans la liste
# A20121008-69654 est bien dans la liste
# A20121008-69656 est bien dans la liste
# A20121008-69660 est bien dans la liste
# A20121008-69663 est bien dans la liste
# A20121008-69667 est bien dans la liste
# A20121008-69668 est bien dans la liste
# A20121009-69678 est bien dans la liste
# A20121009-69684 est bien dans la liste
# A20121009-69685 est bien dans la liste
# A20121009-69686 est bien dans la liste
# A20121009-69691 est bien dans la liste
# A20121009-69693 est bien dans la liste
# A20121009-69697 est bien dans la liste
# A20121009-69698 est bien dans la liste
# A20121009-69700 est bien dans la liste
# A20121009-69701 est bien dans la liste
# A20121009-69703 est bien dans la liste
# A20121009-69704 est bien dans la liste
# A20121009-69706 est bien dans la liste
# A20121009-69707 est bien dans la liste
# A20121009-69708 est bien dans la liste
# A20121009-69709 est bien dans la liste
# A20121009-69710 est bien dans la liste
# A20121009-69712 est bien dans la liste
# A20121009-69717 est bien dans la liste
# A20121009-69719 est bien dans la liste
# A20121009-69721 est bien dans la liste
# A20121010-69731 est bien dans la liste
# A20121010-69732 est bien dans la liste
# A20121010-69736 est bien dans la liste
# ...
# A20130206-39879 est bien dans la liste
# A20130206-39880 est bien dans la liste
# A20130206-39881 est bien dans la liste
# A20130206-39882 est bien dans la liste
# A20130206-40277 est bien dans la liste
# A20130206-40278 est bien dans la liste
# A20130206-40279 est bien dans la liste
# A20130206-40280 est bien dans la liste
# A20130206-40281 est bien dans la liste
# A20130206-40282 est bien dans la liste
# A20130207-40284 est bien dans la liste
# A20130207-40285 est bien dans la liste
# A20130207-40286 est bien dans la liste
# A20130207-40287 est bien dans la liste
# A20130207-40288 est bien dans la liste
# A20130207-40289 est bien dans la liste
# A20130207-40290 est bien dans la liste
# A20130207-40291 est bien dans la liste
# A20130208-40292 est bien dans la liste
# A20130208-40293 est bien dans la liste
# A20130208-40294 est bien dans la liste
# A20130208-40295 est bien dans la liste
# A20130208-40296 est bien dans la liste
# A20130210-40745 est bien dans la liste
# A20130208-40757 est bien dans la liste
# A20130208-40758 est bien dans la liste
# A20130208-40759 est bien dans la liste
# A20130208-40760 est bien dans la liste
# A20130208-40761 est bien dans la liste
# A20130209-40762 est bien dans la liste
# A20130209-40763 est bien dans la liste
# A20130209-40764 est bien dans la liste
# A20130209-40765 est bien dans la liste
# A20130209-40766 est bien dans la liste
# A20130209-40767 est bien dans la liste
# A20130209-40768 est bien dans la liste
# A20130210-40771 est bien dans la liste
# A20130210-40773 est bien dans la liste
# A20130210-40774 est bien dans la liste
# A20130210-40775 est bien dans la liste
# A20130210-40776 est bien dans la liste
# A20130210-40777 est bien dans la liste
# A20130210-40778 est bien dans la liste
# A20130211-40779 est bien dans la liste
# A20130211-40780 est bien dans la liste
# A20130211-40781 est bien dans la liste
# A20130211-40782 est bien dans la liste
# A20130211-40783 est bien dans la liste
# A20130211-40784 est bien dans la liste
# A20130211-40785 est bien dans la liste
# A20130212-41209 est bien dans la liste
# A20130211-41218 est bien dans la liste
# A20130211-41219 est bien dans la liste
# A20130211-41220 est bien dans la liste
# A20130211-41221 est bien dans la liste
# A20130211-41222 est bien dans la liste
# A20130212-41223 est bien dans la liste
# A20130212-41224 est bien dans la liste
# A20130212-41225 est bien dans la liste
# A20130212-41226 est bien dans la liste
# A20130212-41227 est bien dans la liste
# A20130212-41228 est bien dans la liste
# A20130212-41229 est bien dans la liste
# A20130212-41230 est bien dans la liste
# A20130212-41231 est bien dans la liste
# A20130212-41232 est bien dans la liste
# A20130212-41233 est bien dans la liste
# A20130213-41234 est bien dans la liste
# A20130213-41235 est bien dans la liste
# A20130213-41236 est bien dans la liste
# A20130213-41237 est bien dans la liste
# A20130213-41238 est bien dans la liste
# A20130213-41239 est bien dans la liste
# A20130213-41240 est bien dans la liste
# A20130213-41764 est bien dans la liste
# A20130213-41765 est bien dans la liste
# A20130213-41766 est bien dans la liste
# A20130213-41767 est bien dans la liste
# A20130213-41768 est bien dans la liste
# A20130214-41769 est bien dans la liste
# A20130214-41770 est bien dans la liste
# A20130214-41771 est bien dans la liste
# A20130214-41772 est bien dans la liste
# A20130214-41773 est bien dans la liste
# A20130214-41774 est bien dans la liste
# A20130214-41775 est bien dans la liste
# A20130214-41776 est bien dans la liste
# A20130214-41777 est bien dans la liste
# A20130214-41778 est bien dans la liste
# A20130214-41779 est bien dans la liste
# A20130215-41780 est bien dans la liste
# A20130215-41781 est bien dans la liste
# A20130215-41782 est bien dans la liste
# A20130215-41783 est bien dans la liste
# A20130215-41784 est bien dans la liste
# A20130216-42308 est bien dans la liste
# A20130215-42332 est bien dans la liste
# A20130215-42333 est bien dans la liste
# A20130215-42334 est bien dans la liste
# A20130215-42335 est bien dans la liste
# A20130215-42336 est bien dans la liste
# A20130215-42337 est bien dans la liste
# A20130216-42338 est bien dans la liste
# A20130216-42339 est bien dans la liste
# A20130216-42340 est bien dans la liste
# A20130216-42341 est bien dans la liste
# A20130216-42344 est bien dans la liste
# A20130216-42345 est bien dans la liste
# A20130216-42346 est bien dans la liste
# A20130216-42347 est bien dans la liste
# A20130216-42348 est bien dans la liste
# A20130216-42349 est bien dans la liste
# A20130217-42350 est bien dans la liste
# A20130217-42351 est bien dans la liste
# A20130217-42352 est bien dans la liste
# A20130217-42353 est bien dans la liste
# A20130217-42354 est bien dans la liste
# A20130217-42355 est bien dans la liste
# A20130217-42356 est bien dans la liste
# A20130217-42357 est bien dans la liste
# A20130217-42358 est bien dans la liste
# A20130217-42359 est bien dans la liste
# A20130217-42360 est bien dans la liste
# A20130217-42361 est bien dans la liste
# A20130218-42362 est bien dans la liste
# A20130218-42364 est bien dans la liste
# A20130218-42365 est bien dans la liste
# A20130218-42862 est bien dans la liste
# A20130218-42863 est bien dans la liste
# A20130218-42864 est bien dans la liste
# A20130218-42865 est bien dans la liste
# A20130218-42866 est bien dans la liste
# A20130219-42867 est bien dans la liste
# A20130219-42868 est bien dans la liste
# A20130219-42869 est bien dans la liste
# A20130219-42870 est bien dans la liste
# A20130219-42871 est bien dans la liste
# A20130219-42872 est bien dans la liste
# A20130219-42873 est bien dans la liste
# A20130219-42874 est bien dans la liste
# A20130219-42875 est bien dans la liste
# A20130219-42876 est bien dans la liste
# A20130219-42877 est bien dans la liste
# A20130219-42878 est bien dans la liste
# A20130220-42879 est bien dans la liste
# A20130220-42880 est bien dans la liste
# A20130220-42881 est bien dans la liste
# A20130220-42882 est bien dans la liste
# A20130220-42883 est bien dans la liste
# A20130220-42884 est bien dans la liste
# A20130220-42885 est bien dans la liste
# A20130220-43388 est bien dans la liste
# A20130220-43389 est bien dans la liste
# A20130220-43390 est bien dans la liste
# A20130220-43391 est bien dans la liste
# A20130221-43392 est bien dans la liste
# A20130221-43393 est bien dans la liste
# A20130221-43394 est bien dans la liste
# A20130221-43395 est bien dans la liste
# A20130221-43396 est bien dans la liste
# A20130221-43397 est bien dans la liste
# A20130221-43398 est bien dans la liste
# A20130221-43399 est bien dans la liste
# A20130221-43400 est bien dans la liste
# A20130221-43401 est bien dans la liste
# A20130221-43402 est bien dans la liste
# A20130222-43403 est bien dans la liste
# A20130222-43404 est bien dans la liste
# A20130222-43405 est bien dans la liste
# A20130222-43406 est bien dans la liste
# A20130222-43407 est bien dans la liste
# A20130222-43408 est bien dans la liste
# A20130222-43409 est bien dans la liste
# A20130222-43928 est bien dans la liste
# A20130222-43929 est bien dans la liste
# A20130222-43930 est bien dans la liste
# A20130222-43931 est bien dans la liste
# A20130222-43932 est bien dans la liste
# A20130223-43933 est bien dans la liste
# A20130223-43934 est bien dans la liste
# A20130223-43935 est bien dans la liste
# A20130223-43936 est bien dans la liste
# A20130223-43937 est bien dans la liste
# A20130223-43938 est bien dans la liste
# A20130223-43939 est bien dans la liste
# A20130223-43940 est bien dans la liste
# A20130223-43941 est bien dans la liste
# A20130224-43942 est bien dans la liste
# A20130224-43943 est bien dans la liste
# A20130224-43944 est bien dans la liste
# A20130224-43945 est bien dans la liste
# A20130224-43946 est bien dans la liste
# A20130224-43947 est bien dans la liste
# A20130224-43948 est bien dans la liste
# A20130224-43949 est bien dans la liste
# A20130224-43950 est bien dans la liste
# A20130224-43951 est bien dans la liste
# A20130224-43952 est bien dans la liste
# A20130225-43953 est bien dans la liste
# A20130225-43954 est bien dans la liste
# A20130225-43955 est bien dans la liste
# A20130225-43956 est bien dans la liste
# A20130225-43957 est bien dans la liste
# A20130225-43958 est bien dans la liste
# A20130225-43959 est bien dans la liste
# A20130225-43960 est bien dans la liste
# A20130226-44406 est bien dans la liste
# A20130226-44407 est bien dans la liste
# A20130226-44410 est bien dans la liste
# A20130226-44413 est bien dans la liste
# A20130226-44416 est bien dans la liste
# A20130227-44422 est bien dans la liste
# A20130225-44446 est bien dans la liste
# A20130225-44447 est bien dans la liste
# A20130225-44448 est bien dans la liste
# A20130226-44449 est bien dans la liste
# A20130226-44450 est bien dans la liste
# A20130226-44451 est bien dans la liste
# A20130226-44452 est bien dans la liste
# A20130226-44453 est bien dans la liste
# A20130226-44454 est bien dans la liste
# A20130226-44455 est bien dans la liste
# A20130226-44456 est bien dans la liste
# A20130226-44457 est bien dans la liste
# A20130226-44458 est bien dans la liste
# A20130226-44459 est bien dans la liste
# A20130226-44460 est bien dans la liste
# A20130227-44461 est bien dans la liste
# A20130227-44462 est bien dans la liste
# A20130227-44463 est bien dans la liste
# A20130227-44464 est bien dans la liste
# A20130227-44465 est bien dans la liste
# A20130227-44954 est bien dans la liste
# A20130227-44955 est bien dans la liste
# A20130227-44956 est bien dans la liste
# A20130227-44957 est bien dans la liste
# A20130227-44958 est bien dans la liste
# A20130228-44959 est bien dans la liste
# A20130228-44960 est bien dans la liste
# A20130228-44961 est bien dans la liste
# A20130228-44962 est bien dans la liste
# A20130228-44963 est bien dans la liste
# A20130228-44964 est bien dans la liste
# A20130228-44965 est bien dans la liste
# A20130228-44966 est bien dans la liste
# A20130228-44967 est bien dans la liste
# A20130228-44968 est bien dans la liste
# A20130228-44969 est bien dans la liste
# A20130228-44970 est bien dans la liste
# A20130206-61838 est bien dans la liste
# A20130211-62310 est bien dans la liste
# A20130211-62311 est bien dans la liste
# A20130211-62318 est bien dans la liste
# A20130211-62340 est bien dans la liste
# A20130211-62341 est bien dans la liste
# A20130212-62402 est bien dans la liste
# A20130212-62418 est bien dans la liste
# A20130212-62427 est bien dans la liste
# A20130212-62542 est bien dans la liste
# A20130212-62560 est bien dans la liste
# A20130212-62561 est bien dans la liste
# A20130213-62574 est bien dans la liste
# A20130213-62580 est bien dans la liste
# A20130213-62596 est bien dans la liste
# A20130213-62599 est bien dans la liste
# A20130213-62604 est bien dans la liste
# A20130213-62612 est bien dans la liste
# A20130213-62621 est bien dans la liste
# A20130213-62630 est bien dans la liste
# A20130213-62642 est bien dans la liste
# A20130213-62645 est bien dans la liste
# A20130215-62752 est bien dans la liste
# A20130215-62761 est bien dans la liste
# A20130215-62767 est bien dans la liste
# A20130215-62780 est bien dans la liste
# A20130215-62792 est bien dans la liste
# A20130215-62794 est bien dans la liste
# A20130215-62808 est bien dans la liste
# A20130215-62814 est bien dans la liste
# A20130215-62816 est bien dans la liste
# A20130216-62821 est bien dans la liste
# A20130216-62829 est bien dans la liste
# A20130216-62837 est bien dans la liste
# A20130216-62847 est bien dans la liste
# A20130216-62850 est bien dans la liste
# A20130216-62862 est bien dans la liste
# A20130216-62868 est bien dans la liste
# A20130216-62886 est bien dans la liste
# A20130216-62887 est bien dans la liste
# A20130216-62891 est bien dans la liste
# A20130216-62899 est bien dans la liste
# A20130219-63047 est bien dans la liste
# A20130219-63048 est bien dans la liste
# A20130219-63052 est bien dans la liste
# A20130219-63053 est bien dans la liste
# A20130219-63059 est bien dans la liste
# A20130219-63060 est bien dans la liste
# A20130220-63061 est bien dans la liste
# A20130220-63067 est bien dans la liste
# A20130220-63071 est bien dans la liste
# A20130220-63078 est bien dans la liste
# A20130220-63092 est bien dans la liste
# A20130220-63094 est bien dans la liste
# A20130220-63099 est bien dans la liste
# A20130220-63103 est bien dans la liste
# A20130220-63104 est bien dans la liste
# A20130220-63110 est bien dans la liste
# A20130220-63113 est bien dans la liste
# A20130220-63115 est bien dans la liste
# A20130220-63117 est bien dans la liste
# A20130220-63122 est bien dans la liste
# A20130220-63123 est bien dans la liste
# A20130221-63127 est bien dans la liste
# A20130223-63238 est bien dans la liste
# A20130223-63241 est bien dans la liste
# A20130223-63249 est bien dans la liste
# A20130223-63252 est bien dans la liste
# A20130223-63270 est bien dans la liste
# A20130223-63292 est bien dans la liste
# A20130224-63296 est bien dans la liste
# A20130224-63299 est bien dans la liste
# A20130224-63303 est bien dans la liste
# A20130224-63304 est bien dans la liste
# A20130225-63400 est bien dans la liste
# A20130226-63407 est bien dans la liste
# A20130226-63415 est bien dans la liste
# A20130226-63422 est bien dans la liste
# A20130226-63430 est bien dans la liste
# A20130227-63530 est bien dans la liste
# A20130206-67945 est bien dans la liste
# A20130206-67949 est bien dans la liste
# A20130208-68005 est bien dans la liste
# A20130208-68009 est bien dans la liste
# A20130208-68014 est bien dans la liste
# A20130208-68016 est bien dans la liste
# A20130208-68021 est bien dans la liste
# A20130208-68024 est bien dans la liste
# A20130208-68027 est bien dans la liste
# A20130208-68030 est bien dans la liste
# A20130216-68325 est bien dans la liste
# A20130216-68329 est bien dans la liste
# A20130216-68332 est bien dans la liste
# A20130216-68337 est bien dans la liste
# A20130216-68342 est bien dans la liste
# A20130217-68408 est bien dans la liste
# A20130217-68426 est bien dans la liste
# A20130218-68435 est bien dans la liste
# A20130219-68483 est bien dans la liste
# A20130221-68562 est bien dans la liste
# A20130222-68573 est bien dans la liste
# A20130222-68575 est bien dans la liste
# A20130222-68577 est bien dans la liste
# A20130222-68579 est bien dans la liste
# A20130222-68584 est bien dans la liste
# A20130222-68586 est bien dans la liste
# A20130222-68589 est bien dans la liste
# A20130222-68590 est bien dans la liste
# A20130222-68594 est bien dans la liste
# A20130222-68596 est bien dans la liste
# A20130222-68598 est bien dans la liste
# A20130222-68601 est bien dans la liste
# A20130222-68602 est bien dans la liste
# A20130222-68607 est bien dans la liste
# A20130223-68609 est bien dans la liste
# A20130223-68612 est bien dans la liste
# A20130223-68613 est bien dans la liste
# A20130223-68614 est bien dans la liste
# A20130223-68616 est bien dans la liste
# A20130223-68617 est bien dans la liste
# A20130223-68619 est bien dans la liste
# A20130223-68621 est bien dans la liste
# A20130223-68623 est bien dans la liste
# A20130223-68624 est bien dans la liste
# A20130223-68625 est bien dans la liste
# A20130223-68628 est bien dans la liste
# A20130223-68630 est bien dans la liste
# A20130224-68632 est bien dans la liste
# A20130224-68633 est bien dans la liste
# A20130224-68635 est bien dans la liste
# A20130224-68636 est bien dans la liste
# A20130224-68638 est bien dans la liste
# A20130224-68639 est bien dans la liste
# A20130224-68642 est bien dans la liste
# A20130224-68643 est bien dans la liste
# A20130224-68646 est bien dans la liste
# A20130224-68648 est bien dans la liste
# A20130224-68649 est bien dans la liste
# A20130224-68650 est bien dans la liste
# A20130224-68652 est bien dans la liste
# A20130224-68655 est bien dans la liste
# A20130225-68658 est bien dans la liste
# A20130225-68661 est bien dans la liste
# A20130225-68666 est bien dans la liste
# A20130225-68670 est bien dans la liste
# A20130225-68675 est bien dans la liste
# A20130225-68679 est bien dans la liste
# A20130225-68684 est bien dans la liste
# A20130225-68687 est bien dans la liste
# A20130225-68691 est bien dans la liste
# A20130225-68695 est bien dans la liste
# A20130225-68700 est bien dans la liste
# A20130225-68705 est bien dans la liste
# A20130226-68712 est bien dans la liste
# A20130226-68714 est bien dans la liste
# A20130226-68721 est bien dans la liste
# A20130226-68727 est bien dans la liste
# A20130226-68733 est bien dans la liste
# A20130226-68737 est bien dans la liste
# A20130228-68883 est bien dans la liste
# Processing EN.4.2.0.f.profiles.g10.201303.nc
